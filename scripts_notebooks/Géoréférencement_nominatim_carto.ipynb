# %% [markdown]
# A partir des cartes océrisées et indexées à partir du script, on merge les résultats avec les métadonnées qu'on a scrappé au préalable.

# %% [markdown]
# Géoréférencement avec l'API Nominatim

# %% [markdown]
# # GOOGLE COLAB !!

# %% [markdown]
# ##### on a aussi ajouté une condition de distance au résultat de nominatim par rapport à la commune renseignée, pour qu'il n'y ait pas de prédictions aberrantes.

# %%
import pandas as pd
import requests
import time
from google.colab import drive
import os
import math

# --- CONFIGURATION ---
drive.mount('/content/drive')
input_csv = '/content/drive/MyDrive/vaucluse/output/metadata_output_merged.csv'
output_csv = '/content/drive/MyDrive/vaucluse/output/vaucluse_georef_nominatim3.csv'

# Cache pour économiser l'API Nominatim
cache_nominatim = {}

def call_nominatim(query):
    """Interroge Nominatim et met en cache le résultat"""
    if not query or query in cache_nominatim:
        return cache_nominatim.get(query), True

    time.sleep(1.1)  # Respect de la limite de 1 requête / seconde
    url = "https://nominatim.openstreetmap.org/search"
    params = {"q": query, "format": "json", "limit": 1, "addressdetails": 1}
    headers = {"User-Agent": "ProjetCartoVaucluse_Funnel_CSV/1.0"}

    try:
        response = requests.get(url, params=params, headers=headers)
        res_json = response.json()
        if res_json:
            result = {
                "lat": float(res_json[0]["lat"]),
                "lon": float(res_json[0]["lon"]),
                "display_name": res_json[0]["display_name"]
            }
            cache_nominatim[query] = result
            return result, False
    except Exception as e:
        print(f"      ⚠️ Erreur réseau : {e}")

    cache_nominatim[query] = None
    return None, False

def haversine_km(lat1, lon1, lat2, lon2):
    """Distance Haversine en km entre deux points (lat/lon en degrés)."""
    R = 6371.0
    phi1, phi2 = math.radians(lat1), math.radians(lat2)
    dphi = math.radians(lat2 - lat1)
    dlambda = math.radians(lon2 - lon1)
    a = math.sin(dphi/2)**2 + math.cos(phi1) * math.cos(phi2) * math.sin(dlambda/2)**2
    return 2 * R * math.asin(math.sqrt(a))

def is_aberrant_from_commune(final_res, lat_comm, lon_comm, max_km=20):
    """
    True si la coordonnée Nominatim est trop loin du centre de commune.
    - max_km à ajuster (ex : 10, 15, 20, 30).
    """
    if final_res is None:
        return False
    try:
        latn = float(final_res["lat"])
        lonn = float(final_res["lon"])
        latc = float(lat_comm)
        lonc = float(lon_comm)
    except Exception:
        # Si les coordonnées commune sont absentes/inexploitables, on ne bloque pas.
        return False

    d = haversine_km(latn, lonn, latc, lonc)
    return d > max_km

# --- CHARGEMENT ---
df = pd.read_csv(input_csv)
print(f"Lancement du géocodage sur {len(df)} cartes...\n")

MAX_DIST_FROM_COMMUNE_KM = 20  # ajuste (10/15/20/30) selon ton besoin
results_coords = []
results_adresses = []
results_precision = []

# --- BOUCLE DE TRAITEMENT ---
for i, row in df.iterrows():
    city = str(row.get('trans_city', ''))
    monument = str(row.get('trans_monument_uniformise', ''))
    edifice_raw = str(row.get('Édifice', ''))
    hamlet = str(row.get('trans_hamlet_uniformise', ''))

    # Nettoyage de l'édifice (on prend ce qui est après le "--")
    edifice_clean = edifice_raw.split('--')[-1].strip() if '--' in edifice_raw else edifice_raw.strip()

    print(f"[{i+1}/{len(df)}] Analyse : {row['File name']} ({city})")
    lat_comm = row.get('latitude')
    lon_comm = row.get('longitude')

    final_res = None
    source = "commune (fallback)"

    # --- ÉTAPE 1 : Monument uniformisé ---
    if monument and "Aucun" not in monument and monument != "nan":
        query = f"{monument}, {city}, 84, France"
        final_res, _ = call_nominatim(query)
        if final_res and is_aberrant_from_commune(final_res, lat_comm, lon_comm, MAX_DIST_FROM_COMMUNE_KM):
            print(f"   ⚠️ Monument trouvé mais trop loin du centre de commune -> rejet (>{MAX_DIST_FROM_COMMUNE_KM} km)")
            final_res = None
        else:
            if final_res:
                source = "monument_uniformise"

    # --- ÉTAPE 2 : Édifice (si étape 1 échoue) ---
    if not final_res and edifice_clean and edifice_clean != "nan":
        query = f"{edifice_clean}, {city}, 84, France"
        final_res, _ = call_nominatim(query)
        if final_res and is_aberrant_from_commune(final_res, lat_comm, lon_comm, MAX_DIST_FROM_COMMUNE_KM):
            print(f"   ⚠️ Édifice trouvé mais trop loin du centre de commune -> rejet (>{MAX_DIST_FROM_COMMUNE_KM} km)")
            final_res = None
        else:
            if final_res:
                source = "edifice"

    # --- ÉTAPE 3 : Hameau (si étape 2 échoue) ---
    if not final_res and hamlet and "Aucun" not in hamlet and hamlet != "nan":
        query = f"{hamlet}, {city}, 84, France"
        final_res, _ = call_nominatim(query)
        if final_res and is_aberrant_from_commune(final_res, lat_comm, lon_comm, MAX_DIST_FROM_COMMUNE_KM):
            print(f"   ⚠️ Hameau trouvé mais trop loin du centre de commune -> rejet (>{MAX_DIST_FROM_COMMUNE_KM} km)")
            final_res = None
        else:
            if final_res:
                source = "hameau"

    # --- ÉTAPE 4 : Latitude/Longitude existantes (Fallback) ---
    if final_res:
        coords_str = f"{final_res['lat']}, {final_res['lon']}"
        adresse = final_res['display_name']
        print(f"   ✅ Trouvé via {source}")
    else:
        # On utilise les colonnes existantes du CSV
        lat_orig = row.get('latitude')
        lon_orig = row.get('longitude')
        coords_str = f"{lat_orig}, {lon_orig}"
        adresse = "" # Pas d'adresse précise si on est au centre-ville
        print(f"   📍 Repli sur les coordonnées de la commune")

    results_coords.append(coords_str)
    results_adresses.append(adresse)
    results_precision.append(source)

# --- ENREGISTREMENT ---
df['coordonnees_georeferencement'] = results_coords
df['adresse_precise'] = results_adresses
df['source_georef'] = results_precision # Optionnel : pour savoir quel niveau a fonctionné

df.to_csv(output_csv, index=False, encoding='utf-8-sig')
print(f"\n✅ Géocodage terminé ! Fichier sauvegardé : {output_csv}")
# Out:
# Streaming output truncated to the last 5000 lines.
# [388/2835] Analyse : FRAD084_07FI007_0742.jpg (Avignon)
#    ✅ Trouvé via monument_uniformise
# [389/2835] Analyse : FRAD084_07FI007_0095_01.jpg (Avignon)
#    ✅ Trouvé via edifice
# [390/2835] Analyse : FRAD084_07FI007_0126.jpg (Avignon)
#    ✅ Trouvé via edifice
# [391/2835] Analyse : FRAD084_07FI007_0125.jpg (nan)
#    📍 Repli sur les coordonnées de la commune
# [392/2835] Analyse : FRAD084_07FI007_1009.jpg (Avignon)
#    ✅ Trouvé via monument_uniformise
# [393/2835] Analyse : FRAD084_07FI007_0087.jpg (Avignon)
#    ✅ Trouvé via monument_uniformise
# [394/2835] Analyse : FRAD084_07FI007_0833.jpg (Avignon)
#    ✅ Trouvé via monument_uniformise
# [395/2835] Analyse : FRAD084_07FI007_0092.jpg (Avignon)
#    ✅ Trouvé via monument_uniformise
# [396/2835] Analyse : FRAD084_07FI007_0136_01.jpg (Avignon)
#    ✅ Trouvé via monument_uniformise
# [397/2835] Analyse : FRAD084_07FI007_0102_01.jpg (Avignon)
#    ✅ Trouvé via monument_uniformise
# [398/2835] Analyse : FRAD084_07FI007_0962.jpg (Avignon)
#    ✅ Trouvé via monument_uniformise
# [399/2835] Analyse : FRAD084_07FI007_0981.jpg (Avignon)
#    ✅ Trouvé via monument_uniformise
# [400/2835] Analyse : FRAD084_07FI007_0104.jpg (Avignon)
#    ✅ Trouvé via edifice
# [401/2835] Analyse : FRAD084_07FI007_0978.jpg (Avignon)
#    ✅ Trouvé via monument_uniformise
# [402/2835] Analyse : FRAD084_07FI007_0122_01.jpg (Avignon)
#    ✅ Trouvé via monument_uniformise
# [403/2835] Analyse : FRAD084_07FI007_0999_01.jpg (Avignon)
#    ✅ Trouvé via monument_uniformise
# [404/2835] Analyse : FRAD084_07FI007_1001_01.jpg (Avignon)
#    ✅ Trouvé via monument_uniformise
# [405/2835] Analyse : FRAD084_07FI007_0121_01.jpg (Avignon)
#    ✅ Trouvé via edifice
# [406/2835] Analyse : FRAD084_07FI007_0114.jpg (Avignon)
#    ✅ Trouvé via monument_uniformise
# [407/2835] Analyse : FRAD084_07FI007_0979_01.jpg (Avignon)
#    ✅ Trouvé via edifice
# [408/2835] Analyse : FRAD084_07FI007_0952_01.jpg (Avignon)
#    ✅ Trouvé via monument_uniformise
# [409/2835] Analyse : FRAD084_07FI007_0936.jpg (Avignon)
#    ✅ Trouvé via monument_uniformise
# [410/2835] Analyse : FRAD084_07FI007_0193_01.jpg (Avignon)
#    ✅ Trouvé via edifice
# [411/2835] Analyse : FRAD084_07FI007_0967_01.jpg (Avignon)
#    ✅ Trouvé via edifice
# [412/2835] Analyse : FRAD084_07FI007_0059.jpg (Avignon)
#    ✅ Trouvé via monument_uniformise
# [413/2835] Analyse : FRAD084_07FI007_0120.jpg (Avignon)
#    ✅ Trouvé via edifice
# [414/2835] Analyse : FRAD084_07FI007_0091.jpg (Avignon)
#    ✅ Trouvé via monument_uniformise
# [415/2835] Analyse : FRAD084_07FI007_0937_01.jpg (Avignon)
#    ✅ Trouvé via edifice
# [416/2835] Analyse : FRAD084_07FI007_0192.jpg (Avignon)
#    ✅ Trouvé via monument_uniformise
# [417/2835] Analyse : FRAD084_07FI007_0089.jpg (Avignon)
#    ✅ Trouvé via monument_uniformise
# [418/2835] Analyse : FRAD084_07FI007_0965.jpg (Avignon)
#    ✅ Trouvé via monument_uniformise
# [419/2835] Analyse : FRAD084_07FI007_1022.jpg (Avignon)
#    ✅ Trouvé via monument_uniformise
# [420/2835] Analyse : FRAD084_07FI007_1021.jpg (Avignon)
#    ✅ Trouvé via monument_uniformise
# [421/2835] Analyse : FRAD084_07FI007_0127.jpg (Avignon)
#    ✅ Trouvé via monument_uniformise
# [422/2835] Analyse : FRAD084_07FI007_0982.jpg (Avignon)
#    ✅ Trouvé via monument_uniformise
# [423/2835] Analyse : FRAD084_07FI007_0142_01.jpg (nan)
#    📍 Repli sur les coordonnées de la commune
# [424/2835] Analyse : FRAD084_07FI007_0162.jpg (Avignon)
#    ✅ Trouvé via monument_uniformise
# [425/2835] Analyse : FRAD084_07FI007_0188.jpg (Avignon)
#    ✅ Trouvé via monument_uniformise
# [426/2835] Analyse : FRAD084_07FI007_0083.jpg (Avignon)
#    ✅ Trouvé via monument_uniformise
# [427/2835] Analyse : FRAD084_07FI007_0080.jpg (Avignon)
#    ✅ Trouvé via monument_uniformise
# [428/2835] Analyse : FRAD084_07FI007_0987_01.jpg (Avignon)
#    ✅ Trouvé via edifice
# [429/2835] Analyse : FRAD084_07FI007_0988_01.jpg (Avignon)
#    ✅ Trouvé via edifice
# [430/2835] Analyse : FRAD084_07FI007_0088_01.jpg (Avignon)
#    ✅ Trouvé via edifice
# [431/2835] Analyse : FRAD084_07FI007_0977.jpg (Avignon)
#    ✅ Trouvé via edifice
# [432/2835] Analyse : FRAD084_07FI007_0980.jpg (Avignon)
#    ✅ Trouvé via monument_uniformise
# [433/2835] Analyse : FRAD084_07FI007_0973.jpg (Avignon)
#    ✅ Trouvé via edifice
# [434/2835] Analyse : FRAD084_07FI007_0736.jpg (Avignon)
#    ✅ Trouvé via monument_uniformise
# [435/2835] Analyse : FRAD084_07FI007_0194.jpg (Avignon)
#    ✅ Trouvé via monument_uniformise
# [436/2835] Analyse : FRAD084_07FI007_0086.jpg (Avignon)
#    ✅ Trouvé via monument_uniformise
# [437/2835] Analyse : FRAD084_07FI007_0394.jpg (Avignon)
#    ✅ Trouvé via monument_uniformise
# [438/2835] Analyse : FRAD084_07FI007_0119.jpg (Avignon)
#    ✅ Trouvé via monument_uniformise
# [439/2835] Analyse : FRAD084_07FI007_0190_01.jpg (Avignon)
#    ✅ Trouvé via monument_uniformise
# [440/2835] Analyse : FRAD084_07FI007_0081.jpg (Avignon)
#    ✅ Trouvé via monument_uniformise
# [441/2835] Analyse : FRAD084_07FI007_1000.jpg (Avignon)
#    ✅ Trouvé via monument_uniformise
# [442/2835] Analyse : FRAD084_07FI007_0189.jpg (Avignon)
#    ✅ Trouvé via monument_uniformise
# [443/2835] Analyse : FRAD084_07FI007_1003.jpg (Avignon)
#    ✅ Trouvé via monument_uniformise
# [444/2835] Analyse : FRAD084_07FI007_0998.jpg (Avignon)
#    ✅ Trouvé via monument_uniformise
# [445/2835] Analyse : FRAD084_07FI007_0082_01.jpg (Avignon)
#    ✅ Trouvé via monument_uniformise
# [446/2835] Analyse : FRAD084_07FI007_0084.jpg (Avignon)
#    ✅ Trouvé via monument_uniformise
# [447/2835] Analyse : FRAD084_07FI007_0984.jpg (Avignon)
#    ✅ Trouvé via monument_uniformise
# [448/2835] Analyse : FRAD084_07FI007_0200_01.jpg (Avignon)
#    ✅ Trouvé via monument_uniformise
# [449/2835] Analyse : FRAD084_07FI007_0957.jpg (Avignon)
#    ✅ Trouvé via monument_uniformise
# [450/2835] Analyse : FRAD084_07FI007_0161.jpg (Avignon)
#    ✅ Trouvé via monument_uniformise
# [451/2835] Analyse : FRAD084_07FI007_1002.jpg (Avignon)
#    ✅ Trouvé via edifice
# [452/2835] Analyse : FRAD084_07FI007_0169.jpg (Avignon)
#    ✅ Trouvé via monument_uniformise
# [453/2835] Analyse : FRAD084_07FI007_0187.jpg (Avignon)
#    ✅ Trouvé via monument_uniformise
# [454/2835] Analyse : FRAD084_07FI007_0090.jpg (Avignon)
#    ✅ Trouvé via edifice
# [455/2835] Analyse : FRAD084_07FI007_0139.jpg (Avignon)
#    ✅ Trouvé via monument_uniformise
# [456/2835] Analyse : FRAD084_07FI007_0132.jpg (Avignon)
#    ✅ Trouvé via monument_uniformise
# [457/2835] Analyse : FRAD084_07FI007_0186_01.jpg (Avignon)
#    ✅ Trouvé via monument_uniformise
# [458/2835] Analyse : FRAD084_07FI007_0116.jpg (Avignon)
#    ✅ Trouvé via monument_uniformise
# [459/2835] Analyse : FRAD084_07FI007_0118.jpg (Avignon)
#    ✅ Trouvé via monument_uniformise
# [460/2835] Analyse : FRAD084_07FI007_0966_01.jpg (Avignon)
#    ✅ Trouvé via monument_uniformise
# [461/2835] Analyse : FRAD084_07FI007_0134_01.jpg (Avignon)
#    ✅ Trouvé via monument_uniformise
# [462/2835] Analyse : FRAD084_07FI007_0113.jpg (Avignon)
#    ✅ Trouvé via monument_uniformise
# [463/2835] Analyse :   (nan)
#    📍 Repli sur les coordonnées de la commune
# [464/2835] Analyse : FRAD084_07FI007_0100_01.jpg (Avignon)
#    ✅ Trouvé via edifice
# [465/2835] Analyse : FRAD084_07FI007_0923.jpg (nan)
#    📍 Repli sur les coordonnées de la commune
# [466/2835] Analyse : FRAD084_07FI007_0085.jpg (Avignon)
#    ✅ Trouvé via edifice
# [467/2835] Analyse : FRAD084_07FI007_0111_01.jpg (Avignon)
#    ✅ Trouvé via monument_uniformise
# [468/2835] Analyse : FRAD084_07FI007_0115_01.jpg (Avignon)
#    ✅ Trouvé via monument_uniformise
# [469/2835] Analyse : FRAD084_07FI007_0112.jpg (Avignon)
#    ✅ Trouvé via monument_uniformise
# [470/2835] Analyse : FRAD084_07FI007_0138.jpg (Avignon)
#    ✅ Trouvé via monument_uniformise
# [471/2835] Analyse : FRAD084_07FI007_0133.jpg (Avignon)
#    ✅ Trouvé via monument_uniformise
# [472/2835] Analyse : FRAD084_07FI007_0938_01.jpg (Avignon)
#    ✅ Trouvé via edifice
# [473/2835] Analyse : FRAD084_07FI007_0143.jpg (nan)
#    📍 Repli sur les coordonnées de la commune
# [474/2835] Analyse : FRAD084_07FI007_0124_01.jpg (Avignon)
#    ✅ Trouvé via monument_uniformise
# [475/2835] Analyse : FRAD084_07FI007_0983.jpg (Avignon)
#    ✅ Trouvé via monument_uniformise
# [476/2835] Analyse : FRAD084_07FI007_0117.jpg (Avignon)
#    ✅ Trouvé via monument_uniformise
# [477/2835] Analyse : FRAD084_07FI007_0166.jpg (Avignon)
#    ✅ Trouvé via monument_uniformise
# [478/2835] Analyse : FRAD084_07FI007_0738_01.jpg (Avignon)
#    ✅ Trouvé via monument_uniformise
# [479/2835] Analyse : FRAD084_07FI007_0961_01.jpg (Avignon)
#    ✅ Trouvé via edifice
# [480/2835] Analyse : FRAD084_07FI007_0185_01.jpg (Avignon)
#    ✅ Trouvé via monument_uniformise
# [481/2835] Analyse : FRAD084_07FI007_0123.jpg (nan)
#    📍 Repli sur les coordonnées de la commune
# [482/2835] Analyse : FRAD084_07FI007_0972.jpg (nan)
#    📍 Repli sur les coordonnées de la commune
# [483/2835] Analyse : FRAD084_07FI007_0963.jpg (Avignon)
#    ✅ Trouvé via monument_uniformise
# [484/2835] Analyse : FRAD084_07FI007_0135_01.jpg (Avignon)
#    ✅ Trouvé via monument_uniformise
# [485/2835] Analyse : FRAD084_07FI007_0740_01.jpg (Avignon)
#    ✅ Trouvé via monument_uniformise
# [486/2835] Analyse : FRAD084_07FI007_0137.jpg (Avignon)
#    ✅ Trouvé via monument_uniformise
# [487/2835] Analyse : FRAD084_07FI007_0209.jpg (Avignon)
#    ✅ Trouvé via monument_uniformise
# [488/2835] Analyse : FRAD084_07FI007_0093.jpg (Avignon)
#    ✅ Trouvé via monument_uniformise
# [489/2835] Analyse : FRAD084_07FI007_0971_01.jpg (Avignon)
#    ✅ Trouvé via edifice
# [490/2835] Analyse : FRAD084_07FI007_0106_01.jpg (Avignon)
#    ✅ Trouvé via monument_uniformise
# [491/2835] Analyse : FRAD084_07FI007_0195.jpg (Avignon)
#    ✅ Trouvé via monument_uniformise
# [492/2835] Analyse : FRAD084_07FI007_0130.jpg (Avignon)
#    ✅ Trouvé via monument_uniformise
# [493/2835] Analyse : FRAD084_07FI007_0974_01.jpg (nan)
#    📍 Repli sur les coordonnées de la commune
# [494/2835] Analyse : FRAD084_07FI007_0150.jpg (nan)
#    📍 Repli sur les coordonnées de la commune
# [495/2835] Analyse : FRAD084_07FI007_0071.jpg (Avignon)
#    ✅ Trouvé via edifice
# [496/2835] Analyse : FRAD084_07FI007_0196_01.jpg (Avignon)
#    ✅ Trouvé via monument_uniformise
# [497/2835] Analyse : FRAD084_07FI007_1010.jpg (Avignon)
#    ✅ Trouvé via monument_uniformise
# [498/2835] Analyse : FRAD084_07FI007_0198.jpg (Avignon)
#    ✅ Trouvé via monument_uniformise
# [499/2835] Analyse : FRAD084_07FI007_0165.jpg (nan)
#    📍 Repli sur les coordonnées de la commune
# [500/2835] Analyse : FRAD084_07FI007_0107.jpg (Avignon)
#    ✅ Trouvé via monument_uniformise
# [501/2835] Analyse : FRAD084_07FI007_0939_01.jpg (Avignon)
#    ✅ Trouvé via monument_uniformise
# [502/2835] Analyse : FRAD084_07FI007_0067.jpg (Avignon)
#    ✅ Trouvé via monument_uniformise
# [503/2835] Analyse : FRAD084_07FI007_0985_01.jpg (nan)
#    📍 Repli sur les coordonnées de la commune
# [504/2835] Analyse : FRAD084_07FI007_1004.jpg (Avignon)
#    ✅ Trouvé via monument_uniformise
# [505/2835] Analyse : FRAD084_07FI007_0737.jpg (Avignon)
#    ✅ Trouvé via monument_uniformise
# [506/2835] Analyse : FRAD084_07FI007_0140.jpg (Avignon)
#    ✅ Trouvé via monument_uniformise
# [507/2835] Analyse : FRAD084_07FI007_0993_01.jpg (Avignon)
#    ✅ Trouvé via monument_uniformise
# [508/2835] Analyse : FRAD084_07FI007_0170.jpg (Avignon)
#    ✅ Trouvé via edifice
# [509/2835] Analyse : FRAD084_07FI007_0990.jpg (Avignon)
#    ✅ Trouvé via monument_uniformise
# [510/2835] Analyse : FRAD084_07FI007_0151_01.jpg (Avignon)
#    ✅ Trouvé via monument_uniformise
# [511/2835] Analyse : FRAD084_07FI007_0110.jpg (Avignon)
#    ✅ Trouvé via monument_uniformise
# [512/2835] Analyse : FRAD084_07FI007_0131.jpg (Avignon)
#    ✅ Trouvé via monument_uniformise
# [513/2835] Analyse : FRAD084_07FI007_0145.jpg (nan)
#    📍 Repli sur les coordonnées de la commune
# [514/2835] Analyse : FRAD084_07FI007_0976_01.jpg (Avignon)
#    ✅ Trouvé via monument_uniformise
# [515/2835] Analyse : FRAD084_07FI007_0975_01.jpg (Avignon)
#    ✅ Trouvé via monument_uniformise
# [516/2835] Analyse : FRAD084_07FI007_0141.jpg (nan)
#    📍 Repli sur les coordonnées de la commune
# [517/2835] Analyse : FRAD084_07FI007_0129.jpg (Avignon)
#    ✅ Trouvé via monument_uniformise
# [518/2835] Analyse : FRAD084_07FI007_0989.jpg (Avignon)
#    ✅ Trouvé via edifice
# [519/2835] Analyse : FRAD084_07FI007_0197_01.jpg (Avignon)
#    ✅ Trouvé via edifice
# [520/2835] Analyse : FRAD084_07FI007_0148.jpg (Avignon)
#    ✅ Trouvé via monument_uniformise
# [521/2835] Analyse : FRAD084_07FI007_0149_01.jpg (Avignon)
#    ✅ Trouvé via monument_uniformise
# [522/2835] Analyse : FRAD084_07FI007_0986.jpg (Avignon)
#    ✅ Trouvé via monument_uniformise
# [523/2835] Analyse : FRAD084_07FI007_0146.jpg (Avignon)
#    ✅ Trouvé via monument_uniformise
# [524/2835] Analyse : FRAD084_07FI007_0154_01.jpg (Avignon)
#    ✅ Trouvé via edifice
# [525/2835] Analyse : FRAD084_07FI007_0964_01.jpg (Avignon)
#    ✅ Trouvé via monument_uniformise
# [526/2835] Analyse : FRAD084_07FI007_0156.jpg (Avignon)
#    ✅ Trouvé via monument_uniformise
# [527/2835] Analyse : FRAD084_07FI007_0709.jpg (Avignon)
#    ✅ Trouvé via monument_uniformise
# [528/2835] Analyse : FRAD084_07FI007_0713_01.jpg (Avignon)
#    ✅ Trouvé via monument_uniformise
# [529/2835] Analyse : FRAD084_07FI007_0994_01.jpg (Avignon)
#    ✅ Trouvé via monument_uniformise
# [530/2835] Analyse : FRAD084_07FI007_0715.jpg (Avignon)
#    ✅ Trouvé via monument_uniformise
# [531/2835] Analyse : FRAD084_07FI007_0157.jpg (Avignon)
#    ✅ Trouvé via monument_uniformise
# [532/2835] Analyse : FRAD084_07FI007_0997.jpg (Avignon)
#    ✅ Trouvé via monument_uniformise
# [533/2835] Analyse : FRAD084_07FI007_0160_01.jpg (Avignon)
#    ✅ Trouvé via monument_uniformise
# [534/2835] Analyse : FRAD084_07FI007_0158.jpg (Avignon)
#    ✅ Trouvé via monument_uniformise
# [535/2835] Analyse : FRAD084_07FI007_0155.jpg (Avignon)
#    ✅ Trouvé via monument_uniformise
# [536/2835] Analyse : FRAD084_07FI007_1012.jpg (Avignon)
#    ✅ Trouvé via edifice
# [537/2835] Analyse : FRAD084_07FI007_0707.jpg (Avignon)
#    ✅ Trouvé via monument_uniformise
# [538/2835] Analyse : FRAD084_07FI007_0159.jpg (Avignon)
#    ✅ Trouvé via monument_uniformise
# [539/2835] Analyse : FRAD084_07FI007_0926.jpg (Avignon)
#    ✅ Trouvé via monument_uniformise
# [540/2835] Analyse : FRAD084_07FI007_0832.jpg (Avignon)
#    ✅ Trouvé via monument_uniformise
# [541/2835] Analyse : FRAD084_07FI007_0002.jpg (Avignon)
#    ✅ Trouvé via monument_uniformise
# [542/2835] Analyse : FRAD084_07FI007_0003.jpg (Avignon)
#    ✅ Trouvé via monument_uniformise
# [543/2835] Analyse : FRAD084_07FI007_0173_01.jpg (Avignon)
#    ✅ Trouvé via monument_uniformise
# [544/2835] Analyse : FRAD084_07FI007_0745.jpg (Avignon)
#    ✅ Trouvé via monument_uniformise
# [545/2835] Analyse : FRAD084_07FI007_0745BIS_01.jpg (Avignon)
#    ✅ Trouvé via monument_uniformise
# [546/2835] Analyse : FRAD084_07FI007_0167.jpg (Avignon)
#    ✅ Trouvé via monument_uniformise
# [547/2835] Analyse : FRAD084_07FI007_0172_01.jpg (Avignon)
#    ✅ Trouvé via monument_uniformise
# [548/2835] Analyse : FRAD084_07FI007_0690.jpg (Avignon)
#    ✅ Trouvé via monument_uniformise
# [549/2835] Analyse : FRAD084_07FI007_0163.jpg (Avignon)
#    ✅ Trouvé via monument_uniformise
# [550/2835] Analyse : FRAD084_07FI007_0175_01.jpg (Avignon)
#    ✅ Trouvé via monument_uniformise
# [551/2835] Analyse : FRAD084_07FI007_0951_01.jpg (Avignon)
#    ✅ Trouvé via monument_uniformise
# [552/2835] Analyse : FRAD084_07FI007_0991.jpg (Avignon)
#    ✅ Trouvé via monument_uniformise
# [553/2835] Analyse : FRAD084_07FI007_0152.jpg (nan)
#    📍 Repli sur les coordonnées de la commune
# [554/2835] Analyse : FRAD084_07FI007_0128.jpg (Avignon)
#    ✅ Trouvé via edifice
# [555/2835] Analyse : FRAD084_07FI007_0959.jpg (Avignon)
#    ✅ Trouvé via monument_uniformise
# [556/2835] Analyse : FRAD084_07FI007_0164.jpg (Avignon)
#    ✅ Trouvé via monument_uniformise
# [557/2835] Analyse : FRAD084_07FI007_0174.jpg (Avignon)
#    ✅ Trouvé via monument_uniformise
# [558/2835] Analyse :   (nan)
#    📍 Repli sur les coordonnées de la commune
# [559/2835] Analyse : FRAD084_07FI007_0171.jpg (Avignon)
#    ✅ Trouvé via monument_uniformise
# [560/2835] Analyse : FRAD084_07FI007_0744_01.jpg (Avignon)
#    ✅ Trouvé via monument_uniformise
# [561/2835] Analyse : FRAD084_07FI007_0743_01.jpg (Avignon)
#    ✅ Trouvé via monument_uniformise
# [562/2835] Analyse : FRAD084_07FI007_0180.jpg (Avignon)
#    ✅ Trouvé via monument_uniformise
# [563/2835] Analyse : FRAD084_07FI007_0181.jpg (Avignon)
#    ✅ Trouvé via monument_uniformise
# [564/2835] Analyse : FRAD084_07FI007_0179.jpg (Avignon)
#    ✅ Trouvé via monument_uniformise
# [565/2835] Analyse : FRAD084_07FI007_1011.jpg (nan)
#    📍 Repli sur les coordonnées de la commune
# [566/2835] Analyse : FRAD084_07FI007_0996_01.jpg (Avignon)
#    ✅ Trouvé via monument_uniformise
# [567/2835] Analyse : FRAD084_07FI007_0710_01.jpg (Avignon)
#    ✅ Trouvé via edifice
# [568/2835] Analyse : FRAD084_07FI007_0711_01.jpg (Avignon)
#    ✅ Trouvé via monument_uniformise
# [569/2835] Analyse : FRAD084_07FI007_0995_01.jpg (Avignon)
#    ✅ Trouvé via monument_uniformise
# [570/2835] Analyse : FRAD084_07FI007_1013.jpg (Avignon)
#    ✅ Trouvé via monument_uniformise
# [571/2835] Analyse : FRAD084_07FI007_1005.jpg (Avignon)
#    ✅ Trouvé via edifice
# [572/2835] Analyse : FRAD084_07FI007_1072_01.jpg (Avignon)
#    ✅ Trouvé via monument_uniformise
# [573/2835] Analyse : FRAD084_07FI007_0834.jpg (Avignon)
#    ✅ Trouvé via monument_uniformise
# [574/2835] Analyse : FRAD084_07FI007_0177.jpg (Avignon)
#    ✅ Trouvé via monument_uniformise
# [575/2835] Analyse : FRAD084_07FI007_0176_01.jpg (Avignon)
#    ✅ Trouvé via monument_uniformise
# [576/2835] Analyse : FRAD084_07FI007_1014.jpg (Avignon)
#    ✅ Trouvé via monument_uniformise
# [577/2835] Analyse : FRAD084_07FI007_0178.jpg (Avignon)
#    ✅ Trouvé via monument_uniformise
# [578/2835] Analyse : FRAD084_07FI007_0168.jpg (Avignon)
#    ✅ Trouvé via monument_uniformise
# [579/2835] Analyse : FRAD084_07FI007_1008_01.jpg (Avignon)
#    ✅ Trouvé via monument_uniformise
# [580/2835] Analyse : FRAD084_07FI007_0182.jpg (Avignon)
#    ✅ Trouvé via monument_uniformise
# [581/2835] Analyse : FRAD084_07FI007_0183.jpg (Avignon)
#    ✅ Trouvé via monument_uniformise
# [582/2835] Analyse : FRAD084_07FI007_0184.jpg (Avignon)
#    ✅ Trouvé via monument_uniformise
# [583/2835] Analyse : FRAD084_07FI007_0960.jpg (Avignon)
#    ✅ Trouvé via monument_uniformise
# [584/2835] Analyse : FRAD084_07FI007_0955.jpg (Avignon)
#    ✅ Trouvé via monument_uniformise
# [585/2835] Analyse : FRAD084_07FI007_1023.jpg (Avignon)
#    ✅ Trouvé via monument_uniformise
# [586/2835] Analyse : FRAD084_07FI007_0907.jpg (Avignon)
#    ✅ Trouvé via edifice
# [587/2835] Analyse : FRAD084_07FI007_0201.jpg (Avignon)
#    ✅ Trouvé via edifice
# [588/2835] Analyse : FRAD084_07FI007_1006_01.jpg (Avignon)
#    ✅ Trouvé via edifice
# [589/2835] Analyse : FRAD084_07FI007_0205.jpg (Avignon)
#    ✅ Trouvé via monument_uniformise
# [590/2835] Analyse : FRAD084_07FI007_1007.jpg (Avignon)
#    ✅ Trouvé via monument_uniformise
# [591/2835] Analyse : FRAD084_07FI007_0958.jpg (Avignon)
#    ✅ Trouvé via monument_uniformise
# [592/2835] Analyse : FRAD084_07FI007_0992.jpg (Avignon)
#    ✅ Trouvé via monument_uniformise
# [593/2835] Analyse : FRAD084_07FI007_0714_01.jpg (Avignon)
#    ✅ Trouvé via edifice
# [594/2835] Analyse : FRAD084_07FI007_0206.jpg (Avignon)
#    ✅ Trouvé via edifice
# [595/2835] Analyse : FRAD084_07FI007_1015.jpg (Avignon)
#    ✅ Trouvé via edifice
# [596/2835] Analyse : FRAD084_07FI007_0829_01.jpg (Avignon)
#    ✅ Trouvé via monument_uniformise
# [597/2835] Analyse : FRAD084_07FI007_0826.jpg (Avignon)
#    ✅ Trouvé via edifice
# [598/2835] Analyse : FRAD084_07FI007_1017.jpg (Avignon)
#    ✅ Trouvé via monument_uniformise
# [599/2835] Analyse : FRAD084_07FI007_0956.jpg (Avignon)
#    ✅ Trouvé via monument_uniformise
# [600/2835] Analyse : FRAD084_07FI007_0215_01.jpg (Avignon)
#    ✅ Trouvé via monument_uniformise
# [601/2835] Analyse : FRAD084_07FI007_0216.jpg (Avignon)
#    ✅ Trouvé via monument_uniformise
# [602/2835] Analyse : FRAD084_07FI007_0211BIS_01.jpg (Avignon)
#    ✅ Trouvé via monument_uniformise
# [603/2835] Analyse : FRAD084_07FI007_0211.jpg (Avignon)
#    ✅ Trouvé via monument_uniformise
# [604/2835] Analyse : FRAD084_07FI007_0839.jpg (Avignon)
#    ✅ Trouvé via monument_uniformise
# [605/2835] Analyse : FRAD084_07FI007_0835.jpg (Avignon)
#    ✅ Trouvé via monument_uniformise
# [606/2835] Analyse : FRAD084_07FI007_0212.jpg (Avignon)
#    ✅ Trouvé via monument_uniformise
# [607/2835] Analyse : FRAD084_07FI007_0210.jpg (Avignon)
#    ✅ Trouvé via monument_uniformise
# [608/2835] Analyse : FRAD084_07FI007_1016.jpg (Avignon)
#    ✅ Trouvé via monument_uniformise
# [609/2835] Analyse : FRAD084_07FI007_1020.jpg (nan)
#    📍 Repli sur les coordonnées de la commune
# [610/2835] Analyse : FRAD084_07FI007_0838.jpg (Avignon)
#    ✅ Trouvé via monument_uniformise
# [611/2835] Analyse : FRAD084_07FI007_0841.jpg (Avignon)
#    ✅ Trouvé via monument_uniformise
# [612/2835] Analyse : FRAD084_07FI007_0208.jpg (Avignon)
#    ✅ Trouvé via monument_uniformise
# [613/2835] Analyse : FRAD084_07FI007_0842.jpg (Avignon)
#    ✅ Trouvé via monument_uniformise
# [614/2835] Analyse : FRAD084_07FI007_0207.jpg (Avignon)
#    ✅ Trouvé via monument_uniformise
# [615/2835] Analyse : FRAD084_07FI007_0840.jpg (Avignon)
#    ✅ Trouvé via edifice
# [616/2835] Analyse : FRAD084_07FI007_1024.jpg (nan)
#    📍 Repli sur les coordonnées de la commune
# [617/2835] Analyse : FRAD084_07FI007_0213.jpg (Avignon)
#    ✅ Trouvé via monument_uniformise
# [618/2835] Analyse : FRAD084_07FI007_0214.jpg (nan)
#    📍 Repli sur les coordonnées de la commune
# [619/2835] Analyse : FRAD084_07FI007_0712_01.jpg (Avignon)
#    ✅ Trouvé via monument_uniformise
# [620/2835] Analyse : FRAD084_07FI007_0825.jpg (Avignon)
#    ✅ Trouvé via monument_uniformise
# [621/2835] Analyse : FRAD084_07FI007_0232.jpg (Avignon)
#    ✅ Trouvé via edifice
# [622/2835] Analyse : FRAD084_07FI007_0225.jpg (Avignon)
#    ✅ Trouvé via monument_uniformise
# [623/2835] Analyse : FRAD084_07FI007_0226.jpg (Avignon)
#    ✅ Trouvé via monument_uniformise
# [624/2835] Analyse : FRAD084_07FI007_0844.jpg (Avignon)
#    ✅ Trouvé via monument_uniformise
# [625/2835] Analyse : FRAD084_07FI007_0221.jpg (Avignon)
#    ✅ Trouvé via monument_uniformise
# [626/2835] Analyse : FRAD084_07FI007_0222.jpg (Avignon)
#    ✅ Trouvé via monument_uniformise
# [627/2835] Analyse : FRAD084_07FI007_0220.jpg (Avignon)
#    ✅ Trouvé via monument_uniformise
# [628/2835] Analyse : FRAD084_07FI007_0223.jpg (nan)
#    📍 Repli sur les coordonnées de la commune
# [629/2835] Analyse : FRAD084_07FI007_0230.jpg (Avignon)
#    ✅ Trouvé via monument_uniformise
# [630/2835] Analyse : FRAD084_07FI007_0231.jpg (Avignon)
#    ✅ Trouvé via monument_uniformise
# [631/2835] Analyse : FRAD084_07FI007_0228.jpg (Avignon)
#    ✅ Trouvé via monument_uniformise
# [632/2835] Analyse : FRAD084_07FI007_0824.jpg (Avignon)
#    ✅ Trouvé via monument_uniformise
# [633/2835] Analyse : FRAD084_07FI007_0224.jpg (Avignon)
#    ✅ Trouvé via monument_uniformise
# [634/2835] Analyse : FRAD084_07FI007_0843.jpg (Avignon)
#    ✅ Trouvé via edifice
# [635/2835] Analyse : FRAD084_07FI007_0219.jpg (Avignon)
#    ✅ Trouvé via monument_uniformise
# [636/2835] Analyse : FRAD084_07FI007_0229.jpg (nan)
#    📍 Repli sur les coordonnées de la commune
# [637/2835] Analyse : FRAD084_07FI007_0218_01.jpg (Avignon)
#    ✅ Trouvé via monument_uniformise
# [638/2835] Analyse : FRAD084_07FI007_0238.jpg (Avignon)
#    ✅ Trouvé via monument_uniformise
# [639/2835] Analyse : FRAD084_07FI007_0239.jpg (Avignon)
#    ✅ Trouvé via monument_uniformise
# [640/2835] Analyse : FRAD084_07FI007_0846.jpg (Avignon)
#    ✅ Trouvé via monument_uniformise
# [641/2835] Analyse : FRAD084_07FI007_0847.jpg (Avignon)
#    ✅ Trouvé via edifice
# [642/2835] Analyse : FRAD084_07FI007_0248.jpg (Avignon)
#    ✅ Trouvé via edifice
# [643/2835] Analyse : FRAD084_07FI007_0247.jpg (Avignon)
#    ✅ Trouvé via edifice
# [644/2835] Analyse : FRAD084_07FI007_0850.jpg (Avignon)
#    ✅ Trouvé via monument_uniformise
# [645/2835] Analyse : FRAD084_07FI007_0244.jpg (Avignon)
#    ✅ Trouvé via edifice
# [646/2835] Analyse : FRAD084_07FI007_0245_01.jpg (Avignon)
#    ✅ Trouvé via edifice
# [647/2835] Analyse : FRAD084_07FI007_0235_01.jpg (Avignon)
#    ✅ Trouvé via monument_uniformise
# [648/2835] Analyse : FRAD084_07FI007_0849.jpg (Avignon)
#    ✅ Trouvé via monument_uniformise
# [649/2835] Analyse : FRAD084_07FI007_0237.jpg (Avignon)
#    ✅ Trouvé via monument_uniformise
# [650/2835] Analyse : FRAD084_07FI007_0236.jpg (Avignon)
#    ✅ Trouvé via monument_uniformise
# [651/2835] Analyse : FRAD084_07FI007_0246.jpg (Avignon)
#    ✅ Trouvé via edifice
# [652/2835] Analyse : FRAD084_07FI007_0227.jpg (Avignon)
#    ✅ Trouvé via monument_uniformise
# [653/2835] Analyse : FRAD084_07FI007_0845.jpg (Avignon)
#    ✅ Trouvé via edifice
# [654/2835] Analyse : FRAD084_07FI007_0243.jpg (Avignon)
#    ✅ Trouvé via monument_uniformise
# [655/2835] Analyse : FRAD084_07FI007_0242.jpg (Avignon)
#    ✅ Trouvé via monument_uniformise
# [656/2835] Analyse : FRAD084_07FI007_0249.jpg (nan)
#    📍 Repli sur les coordonnées de la commune
# [657/2835] Analyse : FRAD084_07FI007_0255.jpg (Avignon)
#    ✅ Trouvé via monument_uniformise
# [658/2835] Analyse : FRAD084_07FI007_0241.jpg (Avignon)
#    ✅ Trouvé via monument_uniformise
# [659/2835] Analyse : FRAD084_07FI007_0256.jpg (nan)
#    📍 Repli sur les coordonnées de la commune
# [660/2835] Analyse : FRAD084_07FI007_0250.jpg (Avignon)
#    ✅ Trouvé via monument_uniformise
# [661/2835] Analyse : FRAD084_07FI007_0851.jpg (Avignon)
#    ✅ Trouvé via monument_uniformise
# [662/2835] Analyse : FRAD084_07FI007_0254_01.jpg (Avignon)
#    ✅ Trouvé via monument_uniformise
# [663/2835] Analyse : FRAD084_07FI007_0252.jpg (Avignon)
#    ✅ Trouvé via monument_uniformise
# [664/2835] Analyse : FRAD084_07FI007_0251.jpg (Avignon)
#    ✅ Trouvé via edifice
# [665/2835] Analyse : FRAD084_07FI007_0253.jpg (Avignon)
#    ✅ Trouvé via monument_uniformise
# [666/2835] Analyse : FRAD084_07FI007_0852.jpg (Avignon)
#    ✅ Trouvé via edifice
# [667/2835] Analyse : FRAD084_07FI007_0240_01.jpg (nan)
#    📍 Repli sur les coordonnées de la commune
# [668/2835] Analyse : FRAD084_07FI007_0716.jpg (Avignon)
#    ✅ Trouvé via monument_uniformise
# [669/2835] Analyse : FRAD084_07FI007_0257.jpg (nan)
#    📍 Repli sur les coordonnées de la commune
# [670/2835] Analyse : FRAD084_07FI007_0717.jpg (nan)
#    📍 Repli sur les coordonnées de la commune
# [671/2835] Analyse : FRAD084_07FI007_0718_01.jpg (nan)
#    📍 Repli sur les coordonnées de la commune
# [672/2835] Analyse : FRAD084_07FI007_0263.jpg (Avignon)
#    ✅ Trouvé via monument_uniformise
# [673/2835] Analyse : FRAD084_07FI007_0265.jpg (Avignon)
#    ✅ Trouvé via monument_uniformise
# [674/2835] Analyse : FRAD084_07FI007_0261.jpg (Avignon)
#    ✅ Trouvé via monument_uniformise
# [675/2835] Analyse : FRAD084_07FI007_0258.jpg (Avignon)
#    ✅ Trouvé via edifice
# [676/2835] Analyse : FRAD084_07FI007_0264_01.jpg (Avignon)
#    ✅ Trouvé via edifice
# [677/2835] Analyse : FRAD084_07FI007_0267.jpg (Avignon)
#    ✅ Trouvé via edifice
# [678/2835] Analyse : FRAD084_07FI007_0266.jpg (Avignon)
#    ✅ Trouvé via monument_uniformise
# [679/2835] Analyse : FRAD084_07FI007_0259.jpg (Avignon)
#    ✅ Trouvé via monument_uniformise
# [680/2835] Analyse : FRAD084_07FI007_0260.jpg (Avignon)
#    ✅ Trouvé via monument_uniformise
# [681/2835] Analyse : FRAD084_07FI007_0268.jpg (Avignon)
#    ✅ Trouvé via edifice
# [682/2835] Analyse : FRAD084_07FI007_0262.jpg (Avignon)
#    ✅ Trouvé via edifice
# [683/2835] Analyse : FRAD084_07FI007_0719.jpg (nan)
#    📍 Repli sur les coordonnées de la commune
# [684/2835] Analyse : FRAD084_07FI007_0848.jpg (Avignon)
#    ✅ Trouvé via monument_uniformise
# [685/2835] Analyse : FRAD084_07FI007_0233.jpg (Avignon)
#    ✅ Trouvé via monument_uniformise
# [686/2835] Analyse : FRAD084_07FI007_0203.jpg (Avignon)
#    ✅ Trouvé via monument_uniformise
# [687/2835] Analyse : FRAD084_07FI007_0202.jpg (nan)
#    📍 Repli sur les coordonnées de la commune
# [688/2835] Analyse : FRAD084_07FI007_0837.jpg (Avignon)
#    ✅ Trouvé via monument_uniformise
# [689/2835] Analyse : FRAD084_07FI007_0303.jpg (Avignon)
#    ✅ Trouvé via monument_uniformise
# [690/2835] Analyse : FRAD084_07FI007_0304.jpg (Avignon)
#    ✅ Trouvé via monument_uniformise
# [691/2835] Analyse : FRAD084_07FI007_0305.jpg (Avignon)
#    ✅ Trouvé via monument_uniformise
# [692/2835] Analyse : FRAD084_07FI007_0306.jpg (Avignon)
#    ✅ Trouvé via monument_uniformise
# [693/2835] Analyse : FRAD084_07FI007_0307.jpg (Avignon)
#    ✅ Trouvé via monument_uniformise
# [694/2835] Analyse : FRAD084_07FI007_0308.jpg (Avignon)
#    ✅ Trouvé via monument_uniformise
# [695/2835] Analyse : FRAD084_07FI007_0309.jpg (Avignon)
#    ✅ Trouvé via monument_uniformise
# [696/2835] Analyse : FRAD084_07FI007_0310.jpg (Avignon)
#    ✅ Trouvé via edifice
# [697/2835] Analyse : FRAD084_07FI007_0311.jpg (Avignon)
#    ✅ Trouvé via monument_uniformise
# [698/2835] Analyse : FRAD084_07FI007_0312.jpg (Avignon)
#    ✅ Trouvé via monument_uniformise
# [699/2835] Analyse : FRAD084_07FI007_0313.jpg (Avignon)
#    ✅ Trouvé via monument_uniformise
# [700/2835] Analyse : FRAD084_07FI007_0314.jpg (Avignon)
#    ✅ Trouvé via monument_uniformise
# [701/2835] Analyse : FRAD084_07FI007_0315.jpg (Avignon)
#    ✅ Trouvé via monument_uniformise
# [702/2835] Analyse : FRAD084_07FI007_0270.jpg (Avignon)
#    ✅ Trouvé via monument_uniformise
# [703/2835] Analyse : FRAD084_07FI007_0271.jpg (Avignon)
#    ✅ Trouvé via monument_uniformise
# [704/2835] Analyse : FRAD084_07FI007_0272.jpg (Avignon)
#    ✅ Trouvé via monument_uniformise
# [705/2835] Analyse : FRAD084_07FI007_0273.jpg (Avignon)
#    ✅ Trouvé via edifice
# [706/2835] Analyse : FRAD084_07FI007_0274.jpg (Avignon)
#    ✅ Trouvé via monument_uniformise
# [707/2835] Analyse : FRAD084_07FI007_0275.jpg (Avignon)
#    ✅ Trouvé via monument_uniformise
# [708/2835] Analyse : FRAD084_07FI007_0276.jpg (Avignon)
#    ✅ Trouvé via edifice
# [709/2835] Analyse : FRAD084_07FI007_0277.jpg (Avignon)
#    ✅ Trouvé via monument_uniformise
# [710/2835] Analyse : FRAD084_07FI007_0278.jpg (Avignon)
#    ✅ Trouvé via monument_uniformise
# [711/2835] Analyse : FRAD084_07FI007_0279.jpg (Avignon)
#    ✅ Trouvé via monument_uniformise
# [712/2835] Analyse : FRAD084_07FI007_0280.jpg (Avignon)
#    ✅ Trouvé via monument_uniformise
# [713/2835] Analyse : FRAD084_07FI007_0281.jpg (Avignon)
#    ✅ Trouvé via monument_uniformise
# [714/2835] Analyse : FRAD084_07FI007_0282.jpg (Avignon)
#    ✅ Trouvé via monument_uniformise
# [715/2835] Analyse : FRAD084_07FI007_0283.jpg (Avignon)
#    ✅ Trouvé via monument_uniformise
# [716/2835] Analyse : FRAD084_07FI007_0284.jpg (Avignon)
#    ✅ Trouvé via monument_uniformise
# [717/2835] Analyse : FRAD084_07FI007_0285.jpg (Avignon)
#    ✅ Trouvé via monument_uniformise
# [718/2835] Analyse : FRAD084_07FI007_0286.jpg (Avignon)
#    ✅ Trouvé via monument_uniformise
# [719/2835] Analyse : FRAD084_07FI007_0288.jpg (Avignon)
#    ✅ Trouvé via monument_uniformise
# [720/2835] Analyse : FRAD084_07FI007_0853.jpg (Avignon)
#    ✅ Trouvé via monument_uniformise
# [721/2835] Analyse : FRAD084_07FI007_0854.jpg (Avignon)
#    ✅ Trouvé via monument_uniformise
# [722/2835] Analyse : FRAD084_07FI007_0290.jpg (Avignon)
#    ✅ Trouvé via edifice
# [723/2835] Analyse : FRAD084_07FI007_0269.jpg (Avignon)
#    ✅ Trouvé via monument_uniformise
# [724/2835] Analyse : FRAD084_07FI007_0287.jpg (Avignon)
#    ✅ Trouvé via edifice
# [725/2835] Analyse : FRAD084_07FI007_0289.jpg (Avignon)
#    ✅ Trouvé via monument_uniformise
# [726/2835] Analyse : FRAD084_07FI007_0320.jpg (Avignon)
#    ✅ Trouvé via monument_uniformise
# [727/2835] Analyse : FRAD084_07FI007_0291.jpg (Avignon)
#    ✅ Trouvé via monument_uniformise
# [728/2835] Analyse : FRAD084_07FI007_0292.jpg (Avignon)
#    ✅ Trouvé via monument_uniformise
# [729/2835] Analyse : FRAD084_07FI007_0293.jpg (Avignon)
#    ✅ Trouvé via edifice
# [730/2835] Analyse : FRAD084_07FI007_0294.jpg (Avignon)
#    ✅ Trouvé via edifice
# [731/2835] Analyse : FRAD084_07FI007_0295.jpg (Avignon)
#    ✅ Trouvé via edifice
# [732/2835] Analyse : FRAD084_07FI007_0296.jpg (Avignon)
#    ✅ Trouvé via monument_uniformise
# [733/2835] Analyse : FRAD084_07FI007_0297.jpg (Avignon)
#    ✅ Trouvé via monument_uniformise
# [734/2835] Analyse : FRAD084_07FI007_0298.jpg (Avignon)
#    ✅ Trouvé via monument_uniformise
# [735/2835] Analyse : FRAD084_07FI007_0299.jpg (Avignon)
#    ✅ Trouvé via monument_uniformise
# [736/2835] Analyse : FRAD084_07FI007_0300.jpg (Avignon)
#    ✅ Trouvé via monument_uniformise
# [737/2835] Analyse : FRAD084_07FI007_0301.jpg (Avignon)
#    ✅ Trouvé via edifice
# [738/2835] Analyse : FRAD084_07FI007_0302.jpg (Avignon)
#    ✅ Trouvé via monument_uniformise
# [739/2835] Analyse : FRAD084_07FI007_0855.jpg (Avignon)
#    ✅ Trouvé via edifice
# [740/2835] Analyse : FRAD084_07FI007_0317.jpg (Avignon)
#    ✅ Trouvé via monument_uniformise
# [741/2835] Analyse : FRAD084_07FI007_0318.jpg (Avignon)
#    ✅ Trouvé via monument_uniformise
# [742/2835] Analyse : FRAD084_07FI007_0319.jpg (Avignon)
#    ✅ Trouvé via monument_uniformise
# [743/2835] Analyse : FRAD084_07FI007_0856.jpg (Avignon)
#    ✅ Trouvé via monument_uniformise
# [744/2835] Analyse : FRAD084_07FI007_0316.jpg (Avignon)
#    ✅ Trouvé via monument_uniformise
# [745/2835] Analyse : FRAD084_07FI007_1018.jpg (Avignon)
#    ✅ Trouvé via monument_uniformise
# [746/2835] Analyse : FRAD084_07FI007_1019.jpg (Avignon)
#    ✅ Trouvé via monument_uniformise
# [747/2835] Analyse : FRAD084_07FI007_0217.jpg (Avignon)
#    ✅ Trouvé via monument_uniformise
# [748/2835] Analyse : FRAD084_07FI007_0234.jpg (Avignon)
#    ✅ Trouvé via monument_uniformise
# [749/2835] Analyse : FRAD084_07FI007_0321.jpg (Avignon)
#    ✅ Trouvé via monument_uniformise
# [750/2835] Analyse : FRAD084_07FI007_0784_01.jpg (Avignon)
#    ✅ Trouvé via edifice
# [751/2835] Analyse : FRAD084_07FI007_0460_01.jpg (Avignon)
#    ✅ Trouvé via edifice
# [752/2835] Analyse : FRAD084_07FI007_0781_01.jpg (Avignon)
#    ✅ Trouvé via monument_uniformise
# [753/2835] Analyse : FRAD084_07FI007_0908_01.jpg (Avignon)
#    ✅ Trouvé via monument_uniformise
# [754/2835] Analyse : FRAD084_07FI007_0483.jpg (Avignon)
#    📍 Repli sur les coordonnées de la commune
# [755/2835] Analyse : FRAD084_07FI007_0482.jpg (Avignon)
#    📍 Repli sur les coordonnées de la commune
# [756/2835] Analyse : FRAD084_07FI007_0800_01.jpg (Avignon)
#    ✅ Trouvé via edifice
# [757/2835] Analyse : FRAD084_07FI007_0801_01.jpg (Avignon)
#    ✅ Trouvé via edifice
# [758/2835] Analyse : FRAD084_07FI007_0802_01.jpg (Avignon)
#    ✅ Trouvé via edifice
# [759/2835] Analyse : FRAD084_07FI007_0484_01.jpg (Avignon)
#    📍 Repli sur les coordonnées de la commune
# [760/2835] Analyse : FRAD084_07FI007_0812_01.jpg (Avignon)
#    📍 Repli sur les coordonnées de la commune
# [761/2835] Analyse : FRAD084_07FI007_0594.jpg (Avignon)
#    📍 Repli sur les coordonnées de la commune
# [762/2835] Analyse : FRAD084_07FI007_0595.jpg (Avignon)
#    📍 Repli sur les coordonnées de la commune
# [763/2835] Analyse : FRAD084_07FI007_0592.jpg (Avignon)
#    📍 Repli sur les coordonnées de la commune
# [764/2835] Analyse : FRAD084_07FI007_0593_01.jpg (Avignon)
#    📍 Repli sur les coordonnées de la commune
# [765/2835] Analyse : FRAD084_07FI007_0481.jpg (nan)
#    📍 Repli sur les coordonnées de la commune
# [766/2835] Analyse : FRAD084_07FI007_0006.jpg (Avignon)
#    ✅ Trouvé via monument_uniformise
# [767/2835] Analyse : FRAD084_07FI007_0778_01.jpg (Avignon)
#    ✅ Trouvé via edifice
# [768/2835] Analyse : FRAD084_07FI007_0457.jpg (Avignon)
#    ✅ Trouvé via edifice
# [769/2835] Analyse : FRAD084_07FI007_0458_01.jpg (Avignon)
#    ✅ Trouvé via edifice
# [770/2835] Analyse : FRAD084_07FI007_0782_01.jpg (Avignon)
#    ✅ Trouvé via monument_uniformise
# [771/2835] Analyse : FRAD084_07FI007_0799_01.jpg (Avignon)
#    ✅ Trouvé via monument_uniformise
# [772/2835] Analyse : FRAD084_07FI007_0017.jpg (Avignon)
#    ✅ Trouvé via edifice
# [773/2835] Analyse : FRAD084_07FI007_0105.jpg (Avignon)
#    ✅ Trouvé via edifice
# [774/2835] Analyse : FRAD084_07FI007_0101_01.jpg (Avignon)
#    ✅ Trouvé via edifice
# [775/2835] Analyse : FRAD084_07FI007_0098.jpg (Avignon)
#    ✅ Trouvé via edifice
# [776/2835] Analyse : FRAD084_07FI007_0953.jpg (Avignon)
#    ✅ Trouvé via edifice
# [777/2835] Analyse : FRAD084_07FI007_0199.jpg (Avignon)
#    ✅ Trouvé via edifice
# [778/2835] Analyse : FRAD084_07FI007_0493.jpg (Avignon)
#    ✅ Trouvé via edifice
# [779/2835] Analyse : FRAD084_07FI007_0720.jpg (nan)
#    📍 Repli sur les coordonnées de la commune
# [780/2835] Analyse : FRAD084_07FI007_0491.jpg (Avignon)
#    ✅ Trouvé via edifice
# [781/2835] Analyse : FRAD084_07FI007_0489.jpg (Avignon)
#    ✅ Trouvé via edifice
# [782/2835] Analyse : FRAD084_07FI007_0494_01.jpg (nan)
#    📍 Repli sur les coordonnées de la commune
# [783/2835] Analyse : FRAD084_07FI007_0096_01.jpg (Avignon)
#    ✅ Trouvé via edifice
# [784/2835] Analyse : FRAD084_07FI007_0103.jpg (Avignon)
#    ✅ Trouvé via edifice
# [785/2835] Analyse : FRAD084_07FI007_0836.jpg (Avignon)
#    ✅ Trouvé via edifice
# [786/2835] Analyse : FRAD084_07FI007_0099.jpg (Avignon)
#    ✅ Trouvé via edifice
# [787/2835] Analyse : FRAD084_07FI007_0492_01.jpg (Avignon)
#    ✅ Trouvé via edifice
# [788/2835] Analyse : FRAD084_07FI007_0097.jpg (Avignon)
#    ✅ Trouvé via edifice
# [789/2835] Analyse : FRAD084_07FI007_0873.jpg (Avignon)
#    ✅ Trouvé via edifice
# [790/2835] Analyse : FRAD084_07FI007_0490.jpg (Avignon)
#    ✅ Trouvé via edifice
# [791/2835] Analyse : FRAD084_07FI007_0498.jpg (Avignon)
#    ✅ Trouvé via monument_uniformise
# [792/2835] Analyse : FRAD084_07FI007_0499.jpg (Avignon)
#    ✅ Trouvé via edifice
# [793/2835] Analyse : FRAD084_07FI007_0882.jpg (Avignon)
#    ✅ Trouvé via edifice
# [794/2835] Analyse : FRAD084_07FI007_0954.jpg (Avignon)
#    ✅ Trouvé via edifice
# [795/2835] Analyse : FRAD084_07FI007_0144_01.jpg (nan)
#    📍 Repli sur les coordonnées de la commune
# [796/2835] Analyse : FRAD084_07FI007_0108_01.jpg (nan)
#    📍 Repli sur les coordonnées de la commune
# [797/2835] Analyse : FRAD084_07FI007_0109_01.jpg (Avignon)
#    ✅ Trouvé via edifice
# [798/2835] Analyse : FRAD084_07FI007_0496.jpg (Avignon)
#    ✅ Trouvé via edifice
# [799/2835] Analyse : FRAD084_07FI007_0497.jpg (Avignon)
#    ✅ Trouvé via edifice
# [800/2835] Analyse : FRAD084_07FI007_1025.jpg (Avignon)
#    ✅ Trouvé via edifice
# [801/2835] Analyse : FRAD084_07FI007_0495.jpg (Avignon)
#    ✅ Trouvé via edifice
# [802/2835] Analyse : FRAD084_07FI007_0968.jpg (Avignon)
#    ✅ Trouvé via edifice
# [803/2835] Analyse : FRAD084_07FI007_0969_01.jpg (Avignon)
#    ✅ Trouvé via monument_uniformise
# [804/2835] Analyse : FRAD084_07FI007_0708_01.jpg (Avignon)
#    ✅ Trouvé via monument_uniformise
# [805/2835] Analyse : FRAD084_07FI007_0503.jpg (Avignon)
#    ✅ Trouvé via edifice
# [806/2835] Analyse : FRAD084_07FI007_0500.jpg (Avignon)
#    ✅ Trouvé via monument_uniformise
# [807/2835] Analyse : FRAD084_07FI007_0502.jpg (Avignon)
#    ✅ Trouvé via monument_uniformise
# [808/2835] Analyse : FRAD084_07FI007_0881.jpg (Avignon)
#    ✅ Trouvé via monument_uniformise
# [809/2835] Analyse : FRAD084_07FI007_0512.jpg (Avignon)
#    ✅ Trouvé via monument_uniformise
# [810/2835] Analyse : FRAD084_07FI007_0506.jpg (Avignon)
#    ✅ Trouvé via edifice
# [811/2835] Analyse : FRAD084_07FI007_0879.jpg (Avignon)
#    ✅ Trouvé via edifice
# [812/2835] Analyse : FRAD084_07FI007_0878.jpg (Avignon)
#    ✅ Trouvé via monument_uniformise
# [813/2835] Analyse : FRAD084_07FI007_0876.jpg (Avignon)
#    ✅ Trouvé via edifice
# [814/2835] Analyse : FRAD084_07FI007_0501.jpg (Avignon)
#    ✅ Trouvé via monument_uniformise
# [815/2835] Analyse : FRAD084_07FI007_0505_01.jpg (Avignon)
#    ✅ Trouvé via edifice
# [816/2835] Analyse : FRAD084_07FI007_0504.jpg (Avignon)
#    ✅ Trouvé via edifice
# [817/2835] Analyse : FRAD084_07FI007_0507_01.jpg (Avignon)
#    ✅ Trouvé via edifice
# [818/2835] Analyse : FRAD084_07FI007_0508.jpg (Avignon)
#    ✅ Trouvé via monument_uniformise
# [819/2835] Analyse : FRAD084_07FI007_0509.jpg (Avignon)
#    ✅ Trouvé via edifice
# [820/2835] Analyse : FRAD084_07FI007_0510_01.jpg (Avignon)
#    ✅ Trouvé via edifice
# [821/2835] Analyse : FRAD084_07FI007_0511.jpg (Avignon)
#    ✅ Trouvé via edifice
# [822/2835] Analyse : FRAD084_07FI007_0827.jpg (Avignon)
#    ✅ Trouvé via edifice
# [823/2835] Analyse : FRAD084_07FI007_0880.jpg (Avignon)
#    ✅ Trouvé via monument_uniformise
# [824/2835] Analyse : FRAD084_07FI007_0529_01.jpg (Avignon)
#    ✅ Trouvé via edifice
# [825/2835] Analyse : FRAD084_07FI007_0530.jpg (Avignon)
#    ✅ Trouvé via monument_uniformise
# [826/2835] Analyse : FRAD084_07FI007_0531.jpg (Avignon)
#    ✅ Trouvé via edifice
# [827/2835] Analyse : FRAD084_07FI007_0532_01.jpg (Avignon)
#    ✅ Trouvé via monument_uniformise
# [828/2835] Analyse : FRAD084_07FI007_0875.jpg (Avignon)
#    ✅ Trouvé via monument_uniformise
# [829/2835] Analyse : FRAD084_07FI007_0877.jpg (Avignon)
#    ✅ Trouvé via edifice
# [830/2835] Analyse : FRAD084_07FI007_0519_01.jpg (Avignon)
#    ✅ Trouvé via edifice
# [831/2835] Analyse : FRAD084_07FI007_0515_01.jpg (Avignon)
#    ✅ Trouvé via edifice
# [832/2835] Analyse : FRAD084_07FI007_0517.jpg (Avignon)
#    ✅ Trouvé via edifice
# [833/2835] Analyse : FRAD084_07FI007_0874.jpg (Avignon)
#    ✅ Trouvé via edifice
# [834/2835] Analyse : FRAD084_07FI007_0516.jpg (Avignon)
#    ✅ Trouvé via edifice
# [835/2835] Analyse : FRAD084_07FI007_0520.jpg (Avignon)
#    ✅ Trouvé via edifice
# [836/2835] Analyse : FRAD084_07FI007_0513.jpg (Avignon)
#    ✅ Trouvé via edifice
# [837/2835] Analyse : FRAD084_07FI007_0523.jpg (nan)
#    📍 Repli sur les coordonnées de la commune
# [838/2835] Analyse : FRAD084_07FI007_0521.jpg (Avignon)
#    ✅ Trouvé via edifice
# [839/2835] Analyse : FRAD084_07FI007_0518.jpg (Avignon)
#    ✅ Trouvé via edifice
# [840/2835] Analyse : FRAD084_07FI007_0514_01.jpg (Avignon)
#    ✅ Trouvé via edifice
# [841/2835] Analyse : FRAD084_07FI007_0522.jpg (Avignon)
#    ✅ Trouvé via edifice
# [842/2835] Analyse : FRAD084_07FI007_0528.jpg (nan)
#    📍 Repli sur les coordonnées de la commune
# [843/2835] Analyse : FRAD084_07FI007_0721.jpg (nan)
#    📍 Repli sur les coordonnées de la commune
# [844/2835] Analyse : FRAD084_07FI007_0525.jpg (Avignon)
#    ✅ Trouvé via edifice
# [845/2835] Analyse : FRAD084_07FI007_0524.jpg (Avignon)
#    ✅ Trouvé via edifice
# [846/2835] Analyse : FRAD084_07FI007_0527.jpg (Avignon)
#    ✅ Trouvé via edifice
# [847/2835] Analyse : FRAD084_07FI007_0526.jpg (Avignon)
#    ✅ Trouvé via edifice
# [848/2835] Analyse : FRAD084_07FI007_0722_01.jpg (nan)
#    📍 Repli sur les coordonnées de la commune
# [849/2835] Analyse : FRAD084_07FI007_0902.jpg (Avignon)
#    ✅ Trouvé via monument_uniformise
# [850/2835] Analyse : FRAD084_07FI007_0570.jpg (Avignon)
#    ✅ Trouvé via monument_uniformise
# [851/2835] Analyse : FRAD084_07FI007_0571.jpg (Avignon)
#    ✅ Trouvé via edifice
# [852/2835] Analyse : FRAD084_07FI007_0572.jpg (Avignon)
#    ✅ Trouvé via edifice
# [853/2835] Analyse : FRAD084_07FI007_0573.jpg (Avignon)
#    ✅ Trouvé via edifice
# [854/2835] Analyse : FRAD084_07FI007_0901.jpg (Avignon)
#    ✅ Trouvé via edifice
# [855/2835] Analyse : FRAD084_07FI007_0564_01.jpg (Avignon)
#    ✅ Trouvé via monument_uniformise
# [856/2835] Analyse : FRAD084_07FI007_0565.jpg (Avignon)
#    ✅ Trouvé via monument_uniformise
# [857/2835] Analyse : FRAD084_07FI007_0566.jpg (Avignon)
#    ✅ Trouvé via monument_uniformise
# [858/2835] Analyse : FRAD084_07FI007_0567.jpg (Avignon)
#    ✅ Trouvé via monument_uniformise
# [859/2835] Analyse : FRAD084_07FI007_0568_01.jpg (Avignon)
#    ✅ Trouvé via monument_uniformise
# [860/2835] Analyse : FRAD084_07FI007_0569.jpg (nan)
#    📍 Repli sur les coordonnées de la commune
# [861/2835] Analyse : FRAD084_07FI007_0772_01.jpg (nan)
#    📍 Repli sur les coordonnées de la commune
# [862/2835] Analyse : FRAD084_07FI007_0900.jpg (Avignon)
#    ✅ Trouvé via monument_uniformise
# [863/2835] Analyse : FRAD084_07FI007_0533.jpg (Avignon)
#    ✅ Trouvé via monument_uniformise
# [864/2835] Analyse : FRAD084_07FI007_0536.jpg (Avignon)
#    ✅ Trouvé via monument_uniformise
# [865/2835] Analyse : FRAD084_07FI007_0537.jpg (Avignon)
#    ✅ Trouvé via monument_uniformise
# [866/2835] Analyse : FRAD084_07FI007_0538_01.jpg (Avignon)
#    ✅ Trouvé via edifice
# [867/2835] Analyse : FRAD084_07FI007_0538BIS.jpg (Avignon)
#    ✅ Trouvé via monument_uniformise
# [868/2835] Analyse : FRAD084_07FI007_0539.jpg (Avignon)
#    ✅ Trouvé via monument_uniformise
# [869/2835] Analyse : FRAD084_07FI007_0540.jpg (Avignon)
#    ✅ Trouvé via edifice
# [870/2835] Analyse : FRAD084_07FI007_0891.jpg (Avignon)
#    ✅ Trouvé via monument_uniformise
# [871/2835] Analyse : FRAD084_07FI007_0541_01.jpg (Avignon)
#    ✅ Trouvé via monument_uniformise
# [872/2835] Analyse : FRAD084_07FI007_0542.jpg (Avignon)
#    ✅ Trouvé via monument_uniformise
# [873/2835] Analyse : FRAD084_07FI007_0543.jpg (Avignon)
#    ✅ Trouvé via edifice
# [874/2835] Analyse : FRAD084_07FI007_0534_01.jpg (Avignon)
#    ✅ Trouvé via edifice
# [875/2835] Analyse : FRAD084_07FI007_0535.jpg (Avignon)
#    ✅ Trouvé via monument_uniformise
# [876/2835] Analyse : FRAD084_07FI007_0553.jpg (Avignon)
#    ✅ Trouvé via edifice
# [877/2835] Analyse : FRAD084_07FI007_0544_01.jpg (Avignon)
#    ✅ Trouvé via edifice
# [878/2835] Analyse : FRAD084_07FI007_0545.jpg (Avignon)
#    ✅ Trouvé via edifice
# [879/2835] Analyse : FRAD084_07FI007_0546.jpg (Avignon)
#    ✅ Trouvé via monument_uniformise
# [880/2835] Analyse : FRAD084_07FI007_0547.jpg (Avignon)
#    ✅ Trouvé via edifice
# [881/2835] Analyse : FRAD084_07FI007_0548.jpg (Avignon)
#    ✅ Trouvé via edifice
# [882/2835] Analyse : FRAD084_07FI007_0549_01.jpg (Avignon)
#    ✅ Trouvé via monument_uniformise
# [883/2835] Analyse : FRAD084_07FI007_0550.jpg (Avignon)
#    ✅ Trouvé via edifice
# [884/2835] Analyse : FRAD084_07FI007_0551_01.jpg (nan)
#    📍 Repli sur les coordonnées de la commune
# [885/2835] Analyse : FRAD084_07FI007_0552.jpg (nan)
#    📍 Repli sur les coordonnées de la commune
# [886/2835] Analyse : FRAD084_07FI007_0554.jpg (Avignon)
#    ✅ Trouvé via monument_uniformise
# [887/2835] Analyse : FRAD084_07FI007_0555_01.jpg (Avignon)
#    ✅ Trouvé via edifice
# [888/2835] Analyse : FRAD084_07FI007_0556_01.jpg (Avignon)
#    ✅ Trouvé via edifice
# [889/2835] Analyse : FRAD084_07FI007_0892.jpg (Avignon)
#    ✅ Trouvé via edifice
# [890/2835] Analyse : FRAD084_07FI007_0557.jpg (Avignon)
#    ✅ Trouvé via monument_uniformise
# [891/2835] Analyse : FRAD084_07FI007_0558.jpg (Avignon)
#    ✅ Trouvé via edifice
# [892/2835] Analyse : FRAD084_07FI007_0559.jpg (Avignon)
#    ✅ Trouvé via monument_uniformise
# [893/2835] Analyse : FRAD084_07FI007_0561.jpg (Avignon)
#    ✅ Trouvé via edifice
# [894/2835] Analyse : FRAD084_07FI007_0562.jpg (Avignon)
#    ✅ Trouvé via edifice
# [895/2835] Analyse : FRAD084_07FI007_0893.jpg (Avignon)
#    ✅ Trouvé via edifice
# [896/2835] Analyse : FRAD084_07FI007_0560.jpg (Avignon)
#    ✅ Trouvé via edifice
# [897/2835] Analyse : FRAD084_07FI007_0563.jpg (Avignon)
#    ✅ Trouvé via edifice
# [898/2835] Analyse : FRAD084_07FI007_0894.jpg (Avignon)
#    ✅ Trouvé via monument_uniformise
# [899/2835] Analyse : FRAD084_07FI007_0773_01.jpg (Avignon)
#    ✅ Trouvé via edifice
# [900/2835] Analyse : FRAD084_07FI007_0916.jpg (Avignon)
#    ✅ Trouvé via monument_uniformise
# [901/2835] Analyse : FRAD084_07FI007_0917.jpg (Avignon)
#    ✅ Trouvé via edifice
# [902/2835] Analyse : FRAD084_07FI007_0574.jpg (Avignon)
#    📍 Repli sur les coordonnées de la commune
# [903/2835] Analyse : FRAD084_07FI007_0897.jpg (Avignon)
#    📍 Repli sur les coordonnées de la commune
# [904/2835] Analyse : FRAD084_07FI007_0898.jpg (Avignon)
#    📍 Repli sur les coordonnées de la commune
# [905/2835] Analyse : FRAD084_07FI007_0903.jpg (Avignon)
#    ✅ Trouvé via monument_uniformise
# [906/2835] Analyse : FRAD084_07FI007_0575.jpg (Avignon)
#    ✅ Trouvé via monument_uniformise
# [907/2835] Analyse : FRAD084_07FI007_0830.jpg (Avignon)
#       ⚠️ Erreur réseau : Expecting value: line 1 column 1 (char 0)
#    📍 Repli sur les coordonnées de la commune
# [908/2835] Analyse : FRAD084_07FI007_0702_01.jpg (nan)
#    📍 Repli sur les coordonnées de la commune
# [909/2835] Analyse : FRAD084_07FI007_0770.jpg (Avignon)
#    📍 Repli sur les coordonnées de la commune
# [910/2835] Analyse : FRAD084_07FI007_0486.jpg (Avignon)
#    📍 Repli sur les coordonnées de la commune
# [911/2835] Analyse : FRAD084_07FI007_0487.jpg (Avignon)
#    📍 Repli sur les coordonnées de la commune
# [912/2835] Analyse : FRAD084_07FI007_0420.jpg (Avignon)
#    ✅ Trouvé via edifice
# [913/2835] Analyse : FRAD084_07FI007_0421_01.jpg (Avignon)
#    ✅ Trouvé via edifice
# [914/2835] Analyse : FRAD084_07FI007_0886.jpg (Avignon)
#    ✅ Trouvé via edifice
# [915/2835] Analyse : FRAD084_07FI007_0821.jpg (Avignon)
#    ✅ Trouvé via monument_uniformise
# [916/2835] Analyse : FRAD084_07FI007_0428_01.jpg (Avignon)
#    ✅ Trouvé via monument_uniformise
# [917/2835] Analyse : FRAD084_07FI007_0423.jpg (Avignon)
#    ✅ Trouvé via monument_uniformise
# [918/2835] Analyse : FRAD084_07FI007_0448.jpg (Avignon)
#    ✅ Trouvé via monument_uniformise
# [919/2835] Analyse : FRAD084_07FI007_0451_01.jpg (Avignon)
#    ✅ Trouvé via monument_uniformise
# [920/2835] Analyse : FRAD084_07FI007_0413.jpg (Avignon)
#    ✅ Trouvé via monument_uniformise
# ...
#    📍 Repli sur les coordonnées de la commune
# [2675/2835] Analyse : FRAD084_07FI137_0084_01.jpg (Vaison-la-Romaine)
#    ✅ Trouvé via hameau
# [2676/2835] Analyse : FRAD084_07FI137_0121.jpg (Vaison-la-Romaine)
#    📍 Repli sur les coordonnées de la commune
# [2677/2835] Analyse : FRAD084_07FI137_0118.jpg (Vaison-la-Romaine)
#    📍 Repli sur les coordonnées de la commune
# [2678/2835] Analyse : FRAD084_07FI137_0113_01.jpg (Vaison-la-Romaine)
#    ✅ Trouvé via hameau
# [2679/2835] Analyse : FRAD084_07FI137_0114_01.jpg (Vaison-la-Romaine)
#    📍 Repli sur les coordonnées de la commune
# [2680/2835] Analyse : FRAD084_07FI137_0001_01.jpg (Vaison-la-Romaine)
#    📍 Repli sur les coordonnées de la commune
# [2681/2835] Analyse : FRAD084_07FI137_0107_01.jpg (Vaison-la-Romaine)
#    📍 Repli sur les coordonnées de la commune
# [2682/2835] Analyse : FRAD084_07FI137_0111.jpg (Vaison-la-Romaine)
#    ✅ Trouvé via monument_uniformise
# [2683/2835] Analyse : FRAD084_07FI138_0001_01.jpg (nan)
#    📍 Repli sur les coordonnées de la commune
# [2684/2835] Analyse : FRAD084_07FI138_0002_01.jpg (Valréas)
#    ✅ Trouvé via monument_uniformise
# [2685/2835] Analyse : FRAD084_07FI138_0010_01.jpg (Valréas)
#    ✅ Trouvé via hameau
# [2686/2835] Analyse : FRAD084_07FI138_0003.jpg (nan)
#    ⚠️ Édifice trouvé mais trop loin du centre de commune -> rejet (>20 km)
#    📍 Repli sur les coordonnées de la commune
# [2687/2835] Analyse : FRAD084_07FI138_0004.jpg (Valréas)
#    ✅ Trouvé via edifice
# [2688/2835] Analyse : FRAD084_07FI138_0005_01.jpg (Valréas)
#    ✅ Trouvé via edifice
# [2689/2835] Analyse : FRAD084_07FI138_0006_01.jpg (Valréas)
#    ✅ Trouvé via monument_uniformise
# [2690/2835] Analyse : FRAD084_07FI138_0007.jpg (Valréas)
#    ✅ Trouvé via monument_uniformise
# [2691/2835] Analyse : FRAD084_07FI138_0020_01.jpg (Valréas)
#    ✅ Trouvé via monument_uniformise
# [2692/2835] Analyse : FRAD084_07FI138_0009_01.jpg (Valréas)
#    ✅ Trouvé via edifice
# [2693/2835] Analyse : FRAD084_07FI138_0008_01.jpg (Valréas)
#    📍 Repli sur les coordonnées de la commune
# [2694/2835] Analyse : FRAD084_07FI138_0015_01.jpg (nan)
#    📍 Repli sur les coordonnées de la commune
# [2695/2835] Analyse : FRAD084_07FI138_0016.jpg (Valréas)
#    📍 Repli sur les coordonnées de la commune
# [2696/2835] Analyse : FRAD084_07FI138_0011_01.jpg (Valréas)
#    ✅ Trouvé via edifice
# [2697/2835] Analyse : FRAD084_07FI138_0012_01.jpg (Valréas)
#    📍 Repli sur les coordonnées de la commune
# [2698/2835] Analyse : FRAD084_07FI138_0013_01.jpg (Valréas)
#    📍 Repli sur les coordonnées de la commune
# [2699/2835] Analyse : FRAD084_07FI138_0014_01.jpg (Valréas)
#    📍 Repli sur les coordonnées de la commune
# [2700/2835] Analyse : FRAD084_07FI138_0019_01.jpg (Valréas)
#    📍 Repli sur les coordonnées de la commune
# [2701/2835] Analyse : FRAD084_07FI140_0001.jpg (Vaugines)
#    ✅ Trouvé via monument_uniformise
# [2702/2835] Analyse : FRAD084_07FI143_0001.jpg (nan)
#    📍 Repli sur les coordonnées de la commune
# [2703/2835] Analyse : FRAD084_07FI143_0007.jpg (Venasque)
#    📍 Repli sur les coordonnées de la commune
# [2704/2835] Analyse : FRAD084_07FI143_0002_01.jpg (Venasque)
#    📍 Repli sur les coordonnées de la commune
# [2705/2835] Analyse : FRAD084_07FI143_0009_01.jpg (Venasque)
#    ✅ Trouvé via edifice
# [2706/2835] Analyse : FRAD084_07FI143_0006.jpg (Venasque)
#    📍 Repli sur les coordonnées de la commune
# [2707/2835] Analyse : FRAD084_07FI143_0008_01.jpg (Venasque)
#    📍 Repli sur les coordonnées de la commune
# [2708/2835] Analyse : FRAD084_07FI143_0005.jpg (Venasque)
#    📍 Repli sur les coordonnées de la commune
# [2709/2835] Analyse : FRAD084_07FI143_0003.jpg (Venasque)
#    📍 Repli sur les coordonnées de la commune
# [2710/2835] Analyse : FRAD084_07FI143_0004.jpg (Venasque)
#    📍 Repli sur les coordonnées de la commune
# [2711/2835] Analyse : FRAD084_07FI144_0001.jpg (nan)
#    📍 Repli sur les coordonnées de la commune
# [2712/2835] Analyse : FRAD084_07FI144_0006.jpg (Viens)
#    ✅ Trouvé via edifice
# [2713/2835] Analyse : FRAD084_07FI144_0002_01.jpg (nan)
#    📍 Repli sur les coordonnées de la commune
# [2714/2835] Analyse : FRAD084_07FI145_0001.jpg (nan)
#    📍 Repli sur les coordonnées de la commune
# [2715/2835] Analyse : FRAD084_07FI148_0001_01.jpg (Villes-sur-Auzon)
#    📍 Repli sur les coordonnées de la commune
# [2716/2835] Analyse : FRAD084_07FI148_0003.jpg (Villes)
#    📍 Repli sur les coordonnées de la commune
# [2717/2835] Analyse : FRAD084_07FI148_0002_01.jpg (Villes-sur-Auzon)
#    ✅ Trouvé via hameau
# [2718/2835] Analyse : FRAD084_07FI150_0001_01.jpg (Visan)
#    ✅ Trouvé via edifice
# [2719/2835] Analyse : FRAD084_07FI150_0002.jpg (Visan)
#    ✅ Trouvé via hameau
# [2720/2835] Analyse : FRAD084_07FI150_0003_01.jpg (Visan)
#    📍 Repli sur les coordonnées de la commune
# [2721/2835] Analyse : FRAD084_07FI152_0001.jpg (Mont Ventoux)
#    ✅ Trouvé via hameau
# [2722/2835] Analyse : FRAD084_07FI152_0002.jpg (Carpentras)
#    ✅ Trouvé via monument_uniformise
# [2723/2835] Analyse : FRAD084_07FI152_0003.jpg (Carpentras)
#    ✅ Trouvé via monument_uniformise
# [2724/2835] Analyse : FRAD084_07FI152_0005.jpg (Mont Ventoux)
#    ✅ Trouvé via monument_uniformise
# [2725/2835] Analyse : FRAD084_07FI152_0004.jpg (Mont Ventoux)
#    ✅ Trouvé via monument_uniformise
# [2726/2835] Analyse : FRAD084_07FI152_0009.jpg (Mont Ventoux)
#    📍 Repli sur les coordonnées de la commune
# [2727/2835] Analyse : FRAD084_07FI152_0010.jpg (Mont Ventoux)
#    📍 Repli sur les coordonnées de la commune
# [2728/2835] Analyse : FRAD084_07FI152_0011.jpg (Mont Ventoux)
#    📍 Repli sur les coordonnées de la commune
# [2729/2835] Analyse : FRAD084_07FI152_0006.jpg (Carpentras)
#    ✅ Trouvé via hameau
# [2730/2835] Analyse : FRAD084_07FI152_0008.jpg (Mont Ventoux)
#    ✅ Trouvé via hameau
# [2731/2835] Analyse : FRAD084_07FI152_0007.jpg (Mont Ventoux)
#    📍 Repli sur les coordonnées de la commune
# [2732/2835] Analyse : FRAD084_07FI152_0025.jpg (Carpentras)
#    ✅ Trouvé via monument_uniformise
# [2733/2835] Analyse : FRAD084_07FI152_0026.jpg (Carpentras)
#    ✅ Trouvé via monument_uniformise
# [2734/2835] Analyse : FRAD084_07FI152_0027.jpg (Mont Ventoux)
#    📍 Repli sur les coordonnées de la commune
# [2735/2835] Analyse : FRAD084_07FI152_0028.jpg (Mont Ventoux)
#    📍 Repli sur les coordonnées de la commune
# [2736/2835] Analyse : FRAD084_07FI152_0029.jpg (Bédoin)
#    📍 Repli sur les coordonnées de la commune
# [2737/2835] Analyse : FRAD084_07FI152_0109.jpg (Carpentras)
#    ✅ Trouvé via monument_uniformise
# [2738/2835] Analyse : FRAD084_07FI152_0102.jpg (Mont Ventoux)
#    📍 Repli sur les coordonnées de la commune
# [2739/2835] Analyse : FRAD084_07FI152_0101_01.jpg (nan)
#    📍 Repli sur les coordonnées de la commune
# [2740/2835] Analyse : FRAD084_07FI152_0105_01.jpg (nan)
#    ✅ Trouvé via hameau
# [2741/2835] Analyse : FRAD084_07FI152_0031.jpg (Mont Ventoux)
#    ✅ Trouvé via monument_uniformise
# [2742/2835] Analyse : FRAD084_07FI152_0012.jpg (Avignon)
#    📍 Repli sur les coordonnées de la commune
# [2743/2835] Analyse : FRAD084_07FI152_0013.jpg (Avignon)
#    📍 Repli sur les coordonnées de la commune
# [2744/2835] Analyse : FRAD084_07FI152_0014.jpg (Avignon)
#    📍 Repli sur les coordonnées de la commune
# [2745/2835] Analyse : FRAD084_07FI152_0037.jpg (Mont Ventoux)
#    📍 Repli sur les coordonnées de la commune
# [2746/2835] Analyse : FRAD084_07FI152_0036.jpg (Mont Ventoux)
#    📍 Repli sur les coordonnées de la commune
# [2747/2835] Analyse : FRAD084_07FI152_0034.jpg (Carpentras)
#    ✅ Trouvé via monument_uniformise
# [2748/2835] Analyse : FRAD084_07FI152_0040.jpg (Carpentras)
#    ✅ Trouvé via monument_uniformise
# [2749/2835] Analyse : FRAD084_07FI152_0035.jpg (Mont Ventoux)
#    📍 Repli sur les coordonnées de la commune
# [2750/2835] Analyse : FRAD084_07FI152_0032.jpg (Mont Ventoux)
#    ✅ Trouvé via monument_uniformise
# [2751/2835] Analyse : FRAD084_07FI152_0038.jpg (Mont Ventoux)
#    ✅ Trouvé via edifice
# [2752/2835] Analyse : FRAD084_07FI152_0039.jpg (Mont Ventoux)
#    ✅ Trouvé via monument_uniformise
# [2753/2835] Analyse : FRAD084_07FI152_0041.jpg (nan)
#    📍 Repli sur les coordonnées de la commune
# [2754/2835] Analyse : FRAD084_07FI152_0016.jpg (Avignon)
#    📍 Repli sur les coordonnées de la commune
# [2755/2835] Analyse : FRAD084_07FI152_0017.jpg (Avignon)
#    📍 Repli sur les coordonnées de la commune
# [2756/2835] Analyse : FRAD084_07FI152_0056.jpg (Mont Ventoux)
#    ✅ Trouvé via edifice
# [2757/2835] Analyse : FRAD084_07FI152_0058.jpg (Mont Ventoux)
#    ✅ Trouvé via edifice
# [2758/2835] Analyse : FRAD084_07FI152_0057.jpg (Mont Ventoux)
#    ✅ Trouvé via monument_uniformise
# [2759/2835] Analyse : FRAD084_07FI152_0094.jpg (Mont Ventoux)
#    ✅ Trouvé via edifice
# [2760/2835] Analyse : FRAD084_07FI152_0068.jpg (Mont Ventoux)
#    ✅ Trouvé via monument_uniformise
# [2761/2835] Analyse : FRAD084_07FI152_0069.jpg (Mont Ventoux)
#    ✅ Trouvé via edifice
# [2762/2835] Analyse : FRAD084_07FI152_0023.jpg (nan)
#    📍 Repli sur les coordonnées de la commune
# [2763/2835] Analyse : FRAD084_07FI152_0111.jpg (Mont Ventoux)
#    ✅ Trouvé via edifice
# [2764/2835] Analyse : FRAD084_07FI152_0054.jpg (Mont Ventoux)
#    ✅ Trouvé via edifice
# [2765/2835] Analyse : FRAD084_07FI152_0055.jpg (Mont Ventoux)
#    ✅ Trouvé via edifice
# [2766/2835] Analyse : FRAD084_07FI152_0070.jpg (Mont Ventoux)
#    ✅ Trouvé via edifice
# [2767/2835] Analyse : FRAD084_07FI152_0053_01.jpg (Mont Ventoux)
#    ✅ Trouvé via edifice
# [2768/2835] Analyse : FRAD084_07FI152_0065.jpg (Mont Ventoux)
#    ✅ Trouvé via edifice
# [2769/2835] Analyse : FRAD084_07FI152_0064.jpg (Carpentras)
#    ✅ Trouvé via monument_uniformise
# [2770/2835] Analyse : FRAD084_07FI152_0059.jpg (Mont Ventoux)
#    ✅ Trouvé via edifice
# [2771/2835] Analyse : FRAD084_07FI152_0044.jpg (Mont Ventoux)
#    ✅ Trouvé via edifice
# [2772/2835] Analyse : FRAD084_07FI152_0048.jpg (Mont Ventoux)
#    ✅ Trouvé via edifice
# [2773/2835] Analyse : FRAD084_07FI152_0049.jpg (Mont Ventoux)
#    ✅ Trouvé via edifice
# [2774/2835] Analyse : FRAD084_07FI152_0050.jpg (Mont Ventoux)
#    ✅ Trouvé via edifice
# [2775/2835] Analyse : FRAD084_07FI152_0051.jpg (Mont Ventoux)
#    ✅ Trouvé via edifice
# [2776/2835] Analyse : FRAD084_07FI152_0052.jpg (Mont Ventoux)
#    ✅ Trouvé via edifice
# [2777/2835] Analyse : FRAD084_07FI152_0046.jpg (Mont Ventoux)
#    ✅ Trouvé via edifice
# [2778/2835] Analyse : FRAD084_07FI152_0015.jpg (Avignon)
#    📍 Repli sur les coordonnées de la commune
# [2779/2835] Analyse : FRAD084_07FI152_0113_01.jpg (Mont Ventoux)
#    ✅ Trouvé via monument_uniformise
# [2780/2835] Analyse : FRAD084_07FI152_0047.jpg (Mont Ventoux)
#    ✅ Trouvé via edifice
# [2781/2835] Analyse : FRAD084_07FI152_0110_01.jpg (Mont Ventoux)
#    ✅ Trouvé via edifice
# [2782/2835] Analyse : FRAD084_07FI152_0066.jpg (Mont Ventoux)
#    ✅ Trouvé via edifice
# [2783/2835] Analyse : FRAD084_07FI152_0067.jpg (Mont Ventoux)
#    ✅ Trouvé via edifice
# [2784/2835] Analyse : FRAD084_07FI152_0042.jpg (nan)
#    📍 Repli sur les coordonnées de la commune
# [2785/2835] Analyse : FRAD084_07FI152_0112.jpg (Mont Ventoux)
#    ✅ Trouvé via edifice
# [2786/2835] Analyse : FRAD084_07FI152_0071.jpg (Mont Ventoux)
#    ✅ Trouvé via edifice
# [2787/2835] Analyse : FRAD084_07FI152_0106_01.jpg (Mont Ventoux)
#    ✅ Trouvé via edifice
# [2788/2835] Analyse : FRAD084_07FI152_0045.jpg (Mont Ventoux)
#    ✅ Trouvé via edifice
# [2789/2835] Analyse : FRAD084_07FI152_0043.jpg (Mont Ventoux)
#    📍 Repli sur les coordonnées de la commune
# [2790/2835] Analyse : FRAD084_07FI152_0018.jpg (Mont Ventoux)
#    📍 Repli sur les coordonnées de la commune
# [2791/2835] Analyse : FRAD084_07FI152_0019.jpg (Avignon)
#    📍 Repli sur les coordonnées de la commune
# [2792/2835] Analyse : FRAD084_07FI152_0061.jpg (Mont Ventoux)
#    ✅ Trouvé via hameau
# [2793/2835] Analyse : FRAD084_07FI152_0072.jpg (Mont Ventoux)
#    ✅ Trouvé via hameau
# [2794/2835] Analyse : FRAD084_07FI152_0077.jpg (Mont Ventoux)
#    ✅ Trouvé via hameau
# [2795/2835] Analyse : FRAD084_07FI152_0030.jpg (Mont Ventoux)
#    📍 Repli sur les coordonnées de la commune
# [2796/2835] Analyse : FRAD084_07FI152_0033.jpg (Mont Ventoux)
#    📍 Repli sur les coordonnées de la commune
# [2797/2835] Analyse : FRAD084_07FI152_0074.jpg (Mont Ventoux)
#    📍 Repli sur les coordonnées de la commune
# [2798/2835] Analyse : FRAD084_07FI152_0075.jpg (Mont Ventoux)
#    📍 Repli sur les coordonnées de la commune
# [2799/2835] Analyse : FRAD084_07FI152_0073.jpg (Mont Ventoux)
#    📍 Repli sur les coordonnées de la commune
# [2800/2835] Analyse : FRAD084_07FI152_0060.jpg (Avignon)
#    📍 Repli sur les coordonnées de la commune
# [2801/2835] Analyse : FRAD084_07FI152_0062.jpg (Carpentras)
#    ✅ Trouvé via hameau
# [2802/2835] Analyse : FRAD084_07FI152_0063.jpg (Mont Ventoux)
#    📍 Repli sur les coordonnées de la commune
# [2803/2835] Analyse : FRAD084_07FI152_0114.jpg (Mont Ventoux)
#    📍 Repli sur les coordonnées de la commune
# [2804/2835] Analyse : FRAD084_07FI152_0078_01.jpg (Carpentras)
#    📍 Repli sur les coordonnées de la commune
# [2805/2835] Analyse : FRAD084_07FI152_0079_01.jpg (nan)
#    📍 Repli sur les coordonnées de la commune
# [2806/2835] Analyse : FRAD084_07FI152_0080_01.jpg (Carpentras)
#    📍 Repli sur les coordonnées de la commune
# [2807/2835] Analyse : FRAD084_07FI152_0076.jpg (Mont Ventoux)
#    📍 Repli sur les coordonnées de la commune
# [2808/2835] Analyse : FRAD084_07FI152_0081.jpg (Mont Ventoux)
#    📍 Repli sur les coordonnées de la commune
# [2809/2835] Analyse : FRAD084_07FI152_0020.jpg (Avignon)
#    📍 Repli sur les coordonnées de la commune
# [2810/2835] Analyse : FRAD084_07FI152_0022.jpg (Mont Ventoux)
#    📍 Repli sur les coordonnées de la commune
# [2811/2835] Analyse : FRAD084_07FI152_0021.jpg (Avignon)
#    📍 Repli sur les coordonnées de la commune
# [2812/2835] Analyse : FRAD084_07FI152_0082.jpg (Mont Ventoux)
#    📍 Repli sur les coordonnées de la commune
# [2813/2835] Analyse : FRAD084_07FI152_0083.jpg (Mont Ventoux)
#    📍 Repli sur les coordonnées de la commune
# [2814/2835] Analyse : FRAD084_07FI152_0085.jpg (Mont Ventoux)
#    📍 Repli sur les coordonnées de la commune
# [2815/2835] Analyse : FRAD084_07FI152_0084.jpg (Mont Ventoux)
#    ✅ Trouvé via monument_uniformise
# [2816/2835] Analyse : FRAD084_07FI152_0086.jpg (Mont Ventoux)
#    📍 Repli sur les coordonnées de la commune
# [2817/2835] Analyse : FRAD084_07FI152_0090.jpg (Mont Ventoux)
#    ✅ Trouvé via monument_uniformise
# [2818/2835] Analyse : FRAD084_07FI152_0100.jpg (Mont Ventoux)
#    ✅ Trouvé via hameau
# [2819/2835] Analyse : FRAD084_07FI152_0088_01.jpg (Mont Ventoux)
#    ✅ Trouvé via hameau
# [2820/2835] Analyse : FRAD084_07FI152_0089.jpg (Mont Ventoux)
#    📍 Repli sur les coordonnées de la commune
# [2821/2835] Analyse : FRAD084_07FI152_0097.jpg (Mont Ventoux)
#    📍 Repli sur les coordonnées de la commune
# [2822/2835] Analyse : FRAD084_07FI152_0092.jpg (Mont Ventoux)
#    📍 Repli sur les coordonnées de la commune
# [2823/2835] Analyse : FRAD084_07FI152_0095.jpg (Mont Ventoux)
#    📍 Repli sur les coordonnées de la commune
# [2824/2835] Analyse : FRAD084_07FI152_0087.jpg (Mont Ventoux)
#    📍 Repli sur les coordonnées de la commune
# [2825/2835] Analyse : FRAD084_07FI152_0093.jpg (Carpentras)
#    ✅ Trouvé via monument_uniformise
# [2826/2835] Analyse : FRAD084_07FI152_0096.jpg (Mont Ventoux)
#    📍 Repli sur les coordonnées de la commune
# [2827/2835] Analyse : FRAD084_07FI152_0091.jpg (Mont Ventoux)
#    📍 Repli sur les coordonnées de la commune
# [2828/2835] Analyse : FRAD084_07FI152_0098.jpg (Carpentras)
#    ✅ Trouvé via monument_uniformise
# [2829/2835] Analyse : FRAD084_07FI152_0099.jpg (Mont Ventoux)
#    📍 Repli sur les coordonnées de la commune
# [2830/2835] Analyse : FRAD084_07FI153_0001.jpg (Montmirail)
#    📍 Repli sur les coordonnées de la commune
# [2831/2835] Analyse : FRAD084_07FI153_0002.jpg (Dentelles de Montmirail)
#    📍 Repli sur les coordonnées de la commune
# [2832/2835] Analyse : FRAD084_010J1251_0001.jpg (nan)
#    📍 Repli sur les coordonnées de la commune
# [2833/2835] Analyse : FRAD084_07FI153_0003.jpg (Dentelles de Montmirail)
#    📍 Repli sur les coordonnées de la commune
# [2834/2835] Analyse : FRAD084_07FI153_0004_01.jpg (Carpentras)
#    ✅ Trouvé via monument_uniformise
# [2835/2835] Analyse : FRAD084_07FI002_0013.jpg (Ansouis)
#    📍 Repli sur les coordonnées de la commune
#
# ✅ Géocodage terminé ! Fichier sauvegardé : /content/drive/MyDrive/vaucluse/output/vaucluse_georef_nominatim3.csv

# %% [markdown]
# Construction de la carte avec Folium, intégration des cartes postales et renvoi vers le site des archives du vaucluse

# %%
########### CONSTRUCTION DE LA CARTE ##############


from google.colab import drive
import pandas as pd
import folium
from folium.plugins import MarkerCluster
import os
import base64
import re
import requests

# --- 1. CONFIGURATION & CHARTE ---
drive.mount('/content/drive')
file_path = '/content/drive/MyDrive/vaucluse/output/vaucluse_georef_nominatim3.csv'
images_dir = '/content/drive/MyDrive/vaucluse/data'
output_html = '/content/drive/MyDrive/vaucluse/output/carte_vaucluse_interactive4.html'

COLOR_GREEN = "#046B58"  # Vert classique
COLOR_ORANGE = "#E45955" # Orange classique

# --- 2. FONCTIONS UTILES ---

def extract_year(date_str):
    """Extrait l'année d'une chaîne type '[vers 1900]'"""
    years = re.findall(r'\d{4}', str(date_str))
    return int(years[0]) if years else 9999

# --- 3. PRÉPARATION DES DONNÉES ---
df = pd.read_csv(file_path)
df[['lat', 'lon']] = df['coordonnees_georeferencement'].str.split(',', expand=True).astype(float)
df['year'] = df['Dates'].apply(extract_year)
df = df.dropna(subset=['lat', 'lon'])

# --- 4. INITIALISATION DE LA CARTE ---
m = folium.Map(location=[43.92, 5.2], zoom_start=9, tiles='OpenStreetMap')

# 4.1. Chargement Géographique Robuste
dept_url = "https://geo.api.gouv.fr/departements/84?format=geojson&geometry=contour"
comm_url = "https://geo.api.gouv.fr/departements/84/communes?format=geojson&geometry=contour"

try:
    vaucluse_geojson = requests.get(dept_url).json()
    communes_geojson = requests.get(comm_url).json()

    # Extraction de la géométrie
    v_feat = vaucluse_geojson['features'][0] if 'features' in vaucluse_geojson else vaucluse_geojson
    v_geom = v_feat['geometry']

    # 4.2. Création du Masque (Focus Vaucluse)
    # Rectangle mondial
    world_ring = [[-180, -90], [180, -90], [180, 90], [-180, 90], [-180, -90]]
    mask_coords = [world_ring]

    # Ajout des "trous" (rings du Vaucluse)
    if v_geom['type'] == 'Polygon':
        mask_coords.append(v_geom['coordinates'][0])
    elif v_geom['type'] == 'MultiPolygon':
        for poly in v_geom['coordinates']:
            mask_coords.append(poly[0])

    folium.GeoJson(
        {"type": "Feature", "geometry": {"type": "Polygon", "coordinates": mask_coords}},
        style_function=lambda x: {'fillColor': '#000000', 'color': 'none', 'fillOpacity': 0.5},
        interactive=False
    ).add_to(m)

    # 4.3. Frontières
    # Département (Gros trait vert)
    folium.GeoJson(
        vaucluse_geojson,
        style_function=lambda x: {'color': COLOR_GREEN, 'weight': 6, 'fillOpacity': 0},
        interactive=False
    ).add_to(m)

    # Communes (Trait gris fin)
    folium.GeoJson(
        communes_geojson,
        style_function=lambda x: {'color': '#666666', 'weight': 0.4, 'fillOpacity': 0},
        interactive=False
    ).add_to(m)

except Exception as e:
    print(f"Erreur chargement contours : {e}")

# --- 5. CLUSTERS ET MARQUEURS ---

# Tri chronologique des périodes
all_years = sorted([y for y in df['year'].unique() if y != 9999])
decades_keys = sorted(list(set([(y // 10) * 10 for y in all_years])))
if 9999 in df['year'].values: decades_keys.append(9999)

groups = {}
for d in decades_keys:
    label = f"Années {d}" if d != 9999 else "Date inconnue"
    # MarkerCluster par décennie pour fluidité
    groups[d] = MarkerCluster(name=label).add_to(m)

for i, row in df.iterrows():
    d_key = (row['year'] // 10) * 10 if row['year'] != 9999 else 9999
    file_name = row['File name']
    thumb_url = f"https://earchives.vaucluse.fr/api/image/fi/07fi_cartes_postales/{file_name}"
    viewer_url = f"https://v-earchives.vaucluse.fr/viewer/fi/07fi_cartes_postales/{file_name}"

    # Popup avec charte graphique (Garamond pour l'OCR, Century Gothic pour le reste)
    popup_html = f"""
    <div style="width:280px; font-family: 'Century Gothic', 'Segoe UI', sans-serif; color: #333;">
        <h4 style="color:{COLOR_GREEN}; margin:0 0 10px 0; font-size:15px; font-weight: bold;">{row['File name']}</h4>
        <div style="text-align:center; margin-bottom:10px;">
    <a href="{viewer_url}" target="_blank" rel="noopener">
        <img
            src="{thumb_url}"
            alt="Carte postale – miniature"
            style="max-width:100%; border:1px solid #ccc; border-radius:4px;"
            loading="lazy"
            onerror="this.style.display='none'; this.nextElementSibling.style.display='block';"
        >
    </a>
    <div style="font-size:11px; margin-top:4px;">
        <a href="{viewer_url}" target="_blank" style="color:{COLOR_GREEN}; text-decoration:none;">
            Consulter la carte en haute définition
        </a>
    </div>
</div>
        <div style="font-family: 'Garamond', 'Georgia', serif; font-style: italic; font-size: 16px; margin-bottom: 12px; line-height:1.2; border-left: 3px solid {COLOR_GREEN}; padding-left: 8px;">
            "{row.get('trans_ocr_text', '')}"
        </div>
        <div style="font-size: 12px; line-height: 1.6;">
            <b style="color:{COLOR_GREEN};">Date :</b> {row['Dates']}<br>
            <b style="color:{COLOR_GREEN};">Commune :</b> {row.get('Nom géographique', 'N/A')}<br>
            <b style="color:{COLOR_GREEN};">Lieu-dit :</b> {row.get('trans_hamlet_uniformise', 'N/A')}<br>
            <b style="color:{COLOR_GREEN};">Edifice :</b> {row.get('Édifice', 'N/A')}<br>
            <b style="color:{COLOR_GREEN};">Monument :</b> {row.get('trans_monument_uniformise', 'N/A')}
            <hr style="border: 0; border-top: 1px solid #ddd; margin: 10px 0;">
            <span style="font-size: 10px; color: #777;">
                <i>Précision : {row.get('source_georef', 'commune')}</i><br>
                <i>Confiance : {row.get('trans_confidence', 'N/A')}</i>
            </span>
        </div>
    </div>
    """

    color = COLOR_GREEN if 'monument' in str(row.get('source_georef', '')).lower() else COLOR_ORANGE

    folium.Marker(
        location=[row['lat'], row['lon']],
        popup=folium.Popup(popup_html, max_width=300),
        icon=folium.Icon(color='white', icon_color=color, icon='image', prefix='fa')
    ).add_to(groups[d_key])

# --- 6. FINALISATION ---
# Menu de sélection des calques (trié)
folium.LayerControl(collapsed=False).add_to(m)

# Logo du Vaucluse
# --- AJOUT DU LOGO VAUCLUSE (BAS À GAUCHE) ---

logo_url = "https://upload.wikimedia.org/wikipedia/fr/thumb/6/61/Logo-dept-vaucluse-2025.svg/500px-Logo-dept-vaucluse-2025.svg.png?20250602151636"

logo_html = f"""
<div style="
    position: fixed;
    bottom: 50px; left: 20px; width: 120px; height: auto;
    z-index: 9999;
    background-color: rgba(255, 255, 255, 0.8);
    padding: 10px;
    border: 2px solid {COLOR_GREEN};
    border-radius: 5px;
    box-shadow: 2px 2px 5px rgba(0,0,0,0.3);
    ">
    <img src="{logo_url}" style="width: 100%;">
</div>
"""

m.get_root().html.add_child(folium.Element(logo_html))

m.save(output_html)
print(f"✅ Carte générée avec succès : {output_html}")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Erreur chargement contours : 'geometry'
# ✅ Carte générée avec succès : /content/drive/MyDrive/vaucluse/output/carte_vaucluse_interactive4.html

# %% [markdown]
# Il y a un problème dans l'importation des tracés des frontières départementales et communales, mais la carte s'affiche quand même.
